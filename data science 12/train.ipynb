# %%
import os
import torch
import datetime
from torchvision.models import resnet18
from torchvision.transforms import v2
from torchvision.io import read_image
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from torch import nn
from sklearn.metrics import accuracy_score
from utils import extract_data
import warnings
warnings.filterwarnings('ignore')

# %%
device = (torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu'))

# %%
train_path = "../12 dataset/train/"
test_path = "../12 dataset/train/"
validation_path = "../12 dataset/valid/"

# %% [markdown]
# # Подготовка данных

# %%
class CardDataset(Dataset):
    def __init__(self, image_names: str, y, path, transforms=None, normalize=True):
        self.x, self.y = image_names, y
        self.path = path
        self.normalize = normalize
        self.transforms = transforms
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, index):
        image_name = self.x[index]
        image = read_image(self.path + image_name).to(dtype=torch.float, device=device)
        label = self.y[index]
        if self.transforms:
            image, label = self.transforms(image, label)
        if self.normalize:
            image = image / 255
        
        return image, label

# %%
def create_dataloaders(train_path, validation_path, test_path, transforms=None, mode='all'):
    train_dataset = CardDataset(*extract_data(train_path, mode=mode), path=train_path, transforms=transforms)
    
    train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
    valid_dataset = CardDataset(*extract_data(validation_path, mode=mode), path=validation_path)
    
    valid_dataloader = DataLoader(valid_dataset, batch_size=1, shuffle=True)
    test_dataset = CardDataset(*extract_data(test_path, mode=mode), path=test_path)
    
    test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=True)    
    return train_dataloader, valid_dataloader, test_dataloader

# %%
transforms = v2.Compose([
    v2.RandomHorizontalFlip(),
    v2.RandomVerticalFlip(),
    v2.RandomRotation(45),
    v2.RandomChannelPermutation()
    
])

# %% [markdown]
# # Создание модели

# %%
def training_loop(n_epochs, optimizer, scheduler, model, loss_fn, train_loader, validation_loader, ):
    best_score = 0
    best_epoch = 0
    counter = 0
    
    for epoch in range(n_epochs):
        model.train()
        for data, label in train_loader:
            data = data.to(device=device)
            label = label.to(device=device)
            output = model(data)
            loss = loss_fn(output, label)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        scheduler.step()
        model.eval()
        summary_score= 0
        for i, (data, label) in enumerate(validation_loader):
                  
            output = model(data)
            
            summary_score += accuracy_score(label.argmax(1).cpu(), output.argmax(1).cpu())

        validation_score = summary_score/i


        if best_score > validation_score:
            counter += 1
            if counter == 5:
                print(f"Early stop on epoch {epoch}")
                print(f"Weights are loaded from epoch {best_epoch}")
                model.load_state_dict(best_weights)
                break
        else:
            counter = 0
            best_epoch = epoch
            best_score = validation_score
            best_weights = model.state_dict()

        if epoch == 1 or epoch % 5 == 0:

            print('{} Epoch {}, Training loss {}, Validation accuracy {}, lr {}'.format(
                datetime.datetime.now(),
                epoch,
                loss / len(train_loader),
                validation_score,
                scheduler.get_last_lr())
            )

# %%
class CustomModel(nn.Module):
    def __init__(self, in_channels, out_channels, image_size):
        super().__init__()
        self.image_size = image_size
        self.conv1 = nn.Conv2d(in_channels, 16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(16, 8, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(image_size[0] * image_size[1] // 16 * 8, 32)
        self.fc2 = nn.Linear(32, out_channels)

    def forward(self, x):
        out = F.max_pool2d(torch.tanh(self.conv1(x)), 2)
        #print(out.shape)
        out = F.max_pool2d(torch.tanh(self.conv2(out)), 2)
        #print(out.shape)
        out = out.view(-1, (self.image_size[0] // 4) * (self.image_size[1] // 4) * 8)
        #print(out.shape)
        out = torch.tanh(self.fc1(out))
        #print(out.shape)
        out = F.softmax(self.fc2(out))
        return out

# %%
train_dataloader, valid_dataloader, test_dataloader = create_dataloaders(train_path, validation_path, test_path, transforms=None, mode='all')

# %%
resnet_model = resnet18(pretrained=True)
resnet_model.fc = torch.nn.Linear(resnet_model.fc.in_features, 53)
torch.nn.init.xavier_uniform_(resnet_model.fc.weight) 
resnet_model = resnet_model.to(device=device)
optimizer = torch.optim.SGD(resnet_model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer=optimizer, step_size=10)
loss_fn = nn.CrossEntropyLoss()
training_loop(n_epochs=200, optimizer=optimizer, model=resnet_model, loss_fn=loss_fn, scheduler=scheduler,
              train_loader=train_dataloader, validation_loader=valid_dataloader)
torch.save(resnet_model.state_dict(), 'resnet.pt')
# Out:
# 2024-06-02 13:03:12.726141 Epoch 0, Training loss 0.00956401415169239, Validation accuracy 0.03409090909090909, lr [0.0001]
# 2024-06-02 13:04:49.618564 Epoch 1, Training loss 0.007659234572201967, Validation accuracy 0.06439393939393939, lr [0.0001]
# 2024-06-02 13:11:34.936948 Epoch 5, Training loss 0.005884621758013964, Validation accuracy 0.23106060606060605, lr [0.0001]
# 2024-06-02 13:20:03.957026 Epoch 10, Training loss 0.006288644392043352, Validation accuracy 0.3560606060606061, lr [1e-05]
# 2024-06-02 13:28:39.618925 Epoch 15, Training loss 0.005566319916397333, Validation accuracy 0.38636363636363635, lr [1e-05]
# 2024-06-02 13:37:08.817674 Epoch 20, Training loss 0.007394666317850351, Validation accuracy 0.4015151515151515, lr [1.0000000000000002e-06]
# 2024-06-02 13:45:35.758195 Epoch 25, Training loss 0.006321731023490429, Validation accuracy 0.3712121212121212, lr [1.0000000000000002e-06]
# 2024-06-02 13:54:01.586106 Epoch 30, Training loss 0.006115943193435669, Validation accuracy 0.36363636363636365, lr [1.0000000000000002e-07]
# Early stop on epoch 31
# Weights are loaded from epoch 26

# %% [markdown]
# # Модель, определяющая масть карты

# %%
train_dataloader, valid_dataloader, test_dataloader = create_dataloaders(train_path, validation_path, test_path, mode='suits', transforms=None)

# %%
suit_resnet = resnet18(pretrained=True)
suit_resnet.fc = torch.nn.Linear(suit_resnet.fc.in_features, 5)
torch.nn.init.xavier_uniform_(suit_resnet.fc.weight) 
suit_resnet = suit_resnet.to(device=device)
optimizer = torch.optim.SGD(suit_resnet.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer=optimizer, step_size=10)
loss_fn = nn.CrossEntropyLoss()
training_loop(n_epochs=200, optimizer=optimizer, model=suit_resnet, loss_fn=loss_fn, scheduler=scheduler,
              train_loader=train_dataloader, validation_loader=valid_dataloader)
torch.save(suit_resnet.state_dict(), 'suits_resnet.pt')
# Out:
# 2024-06-02 13:57:25.033806 Epoch 0, Training loss 0.0016486214008182287, Validation accuracy 0.6553030303030303, lr [0.0001]
# 2024-06-02 13:59:07.561119 Epoch 1, Training loss 0.0014357516774907708, Validation accuracy 0.7954545454545454, lr [0.0001]
# 2024-06-02 14:05:55.386822 Epoch 5, Training loss 0.0008385844412259758, Validation accuracy 0.8901515151515151, lr [0.0001]
# 2024-06-02 14:14:23.199041 Epoch 10, Training loss 0.0004816995933651924, Validation accuracy 0.9128787878787878, lr [1e-05]
# 2024-06-02 14:24:06.807578 Epoch 15, Training loss 0.0013270593481138349, Validation accuracy 0.9166666666666666, lr [1e-05]
# Early stop on epoch 16
# Weights are loaded from epoch 11

# %% [markdown]
# # Модель, определяющая значение на карте

# %%
train_dataloader, valid_dataloader, test_dataloader = create_dataloaders(train_path, validation_path, test_path, mode='values')

# %%
value_resnet = resnet18(pretrained=True)
value_resnet.fc = torch.nn.Linear(value_resnet.fc.in_features, 14)
torch.nn.init.xavier_uniform_(value_resnet.fc.weight) 
value_resnet = value_resnet.to(device=device)
optimizer = torch.optim.SGD(value_resnet.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer=optimizer, step_size=10)
loss_fn = nn.CrossEntropyLoss()
training_loop(n_epochs=200, optimizer=optimizer, model=value_resnet, loss_fn=loss_fn, scheduler=scheduler,
              train_loader=train_dataloader, validation_loader=valid_dataloader)
torch.save(value_resnet.state_dict(), 'values_resnet.pt')
# Out:
# 2024-06-02 14:28:05.925136 Epoch 0, Training loss 0.004823051393032074, Validation accuracy 0.20454545454545456, lr [0.0001]
# 2024-06-02 14:30:03.095530 Epoch 1, Training loss 0.004786588251590729, Validation accuracy 0.29924242424242425, lr [0.0001]
# 2024-06-02 14:37:57.248611 Epoch 5, Training loss 0.004153539892286062, Validation accuracy 0.4772727272727273, lr [0.0001]
# 2024-06-02 14:47:49.600471 Epoch 10, Training loss 0.002401385921984911, Validation accuracy 0.5833333333333334, lr [1e-05]
# 2024-06-02 14:57:47.607993 Epoch 15, Training loss 0.0029041848611086607, Validation accuracy 0.6022727272727273, lr [1e-05]
# Early stop on epoch 19
# Weights are loaded from epoch 14

# %% [markdown]
# # Тестирование моделей

# %%
def test_model(model, dataloader: DataLoader):
    counter = 0
    for item, label in dataloader:
        item = item.to(device=device)
        label = label.to(device=device)
        print(model(item).argmax(1), label.argmax(1))
        if torch.equal(model(item).argmax(1), label.argmax(1)):
        #if model(item) == label:
            counter += 1
    return counter / len(dataloader.dataset)

# %%
test_model(value_resnet, train_dataloader)
# Out:
# tensor([ 2,  2, 12,  8,  0,  3, 10,  8,  1,  3, 12,  3,  3,  2, 12, 12],
#        device='cuda:0') tensor([ 2,  2, 12,  1,  1, 11, 10,  8,  1,  3,  2,  3,  5, 11, 12, 12],
#        device='cuda:0')
# tensor([ 2,  2,  3,  6, 12,  0,  5,  0, 11,  9,  0,  9, 13,  1,  1,  6],
#        device='cuda:0') tensor([ 2,  2,  3,  9,  7,  9,  5,  0,  1,  2,  0,  9, 13,  2,  1,  6],
#        device='cuda:0')
# tensor([ 2,  9,  5, 11,  3,  3,  3,  0,  2,  3,  1,  6, 13,  7,  9, 13],
#        device='cuda:0') tensor([ 7,  8,  5, 11,  3,  7,  5, 10,  2,  3,  2,  6,  2,  7,  9, 13],
#        device='cuda:0')
# tensor([ 2,  1, 13, 13,  9, 10,  3,  2,  0,  7,  2, 12,  1,  6,  7,  4],
#        device='cuda:0') tensor([ 2,  9,  2, 13,  9, 10,  3,  2,  9,  6, 12, 12,  1,  6,  5,  7],
#        device='cuda:0')
# tensor([10, 11,  2,  6,  3, 11,  6, 10,  5,  9,  3, 10,  3, 11,  9,  8],
#        device='cuda:0') tensor([ 7,  6, 12,  6,  1,  8,  6, 10,  5,  6,  3, 10, 10, 11,  9, 10],
#        device='cuda:0')
# tensor([ 3,  2,  5,  3,  2,  6,  9,  7,  6, 12,  8,  2,  9,  8, 13,  9],
#        device='cuda:0') tensor([ 3,  2,  7,  9, 13,  6,  0,  7,  6, 12,  8, 12,  9,  8, 13,  9],
#        device='cuda:0')
# tensor([11,  1,  6, 12,  3, 10,  7, 13,  0,  3, 10,  5,  9,  3,  8,  6],
#        device='cuda:0') tensor([11,  1,  6, 13,  3, 10,  7, 13,  0,  3, 10,  5,  1,  3,  8,  6],
#        device='cuda:0')
# tensor([ 6, 10, 11, 10,  0, 11,  3, 10, 12,  6,  3,  1, 10,  8,  8,  8],
#        device='cuda:0') tensor([ 0,  9, 11, 10,  7, 11,  3, 10, 12,  6,  3,  1,  8,  8,  8,  8],
#        device='cuda:0')
# tensor([ 3, 12,  0, 10,  3, 12, 11,  1,  9,  3,  3,  2,  3,  3,  9,  1],
#        device='cuda:0') tensor([ 6,  8,  9, 10,  3, 12, 11,  1,  9,  3,  2,  2,  3,  9,  9,  1],
#        device='cuda:0')
# tensor([13,  7, 11,  2,  3,  6,  7, 13,  1,  6,  5, 12, 11,  3,  8,  1],
#        device='cuda:0') tensor([11,  7,  7,  2,  3,  9,  7, 13,  1,  6,  5, 12, 11,  3,  8,  1],
#        device='cuda:0')
# tensor([ 0, 13,  0, 13,  2, 11,  5,  0,  7,  5, 12,  3,  0,  0,  8,  2],
#        device='cuda:0') tensor([ 0, 13,  0, 11,  2, 11,  5, 10,  7,  5, 12,  3,  0,  0, 11,  2],
#        device='cuda:0')
# tensor([ 8,  6,  0,  5,  8, 13,  6,  7,  3,  7, 13, 12,  3, 10,  8, 12],
#        device='cuda:0') tensor([ 8,  6,  0,  5,  8,  8,  6,  3,  3,  7, 13, 12,  3,  0,  8, 12],
#        device='cuda:0')
# tensor([10,  9, 11, 12, 11,  1,  3, 13,  3,  7,  2,  9, 13,  3, 11,  9],
#        device='cuda:0') tensor([10,  0, 11,  2,  4,  2,  3, 13,  3,  7,  2,  6, 13,  3, 11,  0],
#        device='cuda:0')
# tensor([ 2,  8,  5, 12, 13,  0, 11, 12,  2,  8, 13,  2,  1, 10, 11, 10],
#        device='cuda:0') tensor([ 2, 12,  5, 12, 10, 10, 12, 12,  2,  8, 13,  2,  1, 11, 12, 10],
#        device='cuda:0')
# tensor([ 5, 10,  1,  6, 10, 11,  1, 13, 12,  9, 11,  8,  3,  1,  1,  2],
#        device='cuda:0') tensor([ 5,  0,  1,  6, 10, 11,  1, 13,  7,  9, 11,  8,  7,  1,  1, 11],
#        device='cuda:0')
# tensor([11, 12, 12, 10,  8,  7,  5, 12,  8,  1,  6, 13,  2,  9,  9,  8],
#        device='cuda:0') tensor([11,  0, 12, 10,  8,  7,  5, 11,  5,  1,  6, 13,  2,  1,  3,  0],
#        device='cuda:0')
# tensor([10, 13,  3,  9,  0,  2,  8, 13, 10,  8,  9,  0,  0,  1,  3, 12],
#        device='cuda:0') tensor([10, 13,  5,  9,  8,  2,  6,  1,  6,  8,  9,  6,  0,  1,  3,  2],
#        device='cuda:0')
# tensor([13, 13,  8,  5, 12,  5,  7,  2,  0,  8,  0,  9,  1,  7,  6, 10],
#        device='cuda:0') tensor([13, 13,  9,  5, 12,  5,  7,  2, 10,  9,  0,  6,  9,  7,  6, 10],
#        device='cuda:0')
# tensor([11,  7, 10,  5,  5,  5,  3,  2, 10,  7,  9,  3,  1,  8,  3,  1],
#        device='cuda:0') tensor([11,  7,  0,  5,  3,  5,  1, 11, 10,  7,  1,  5,  2,  8,  3,  1],
#        device='cuda:0')
# tensor([10,  4,  0,  2,  5,  1,  0,  8,  2, 10, 12, 11,  9,  9, 10,  5],
#        device='cuda:0') tensor([ 2,  4,  0,  2,  5,  1,  0,  8,  2, 10, 12, 11,  9,  2,  2,  5],
#        device='cuda:0')
# tensor([ 6,  2, 13,  8,  7, 11, 12,  9,  1, 12,  6, 12,  4, 12, 10,  8],
#        device='cuda:0') tensor([ 6,  2, 13,  8,  3, 11,  3,  9,  1, 12,  9,  1,  4, 12,  6,  8],
#        device='cuda:0')
# tensor([ 3,  7,  7,  3,  2,  0,  7,  5,  3,  5,  9,  1,  5,  6, 12,  2],
#        device='cuda:0') tensor([5, 2, 5, 7, 3, 6, 7, 5, 7, 5, 1, 1, 5, 6, 1, 2], device='cuda:0')
# tensor([12,  7,  0,  3, 10,  3, 13,  9,  7, 13, 10, 11,  5,  3,  8,  5],
#        device='cuda:0') tensor([12,  7,  0,  5,  9,  3, 13,  9,  3, 13, 10, 11,  5,  5,  8,  3],
#        device='cuda:0')
# tensor([ 1,  5,  2,  3,  2,  0,  3, 13,  7,  4,  0,  6, 12, 13, 12,  1],
#        device='cuda:0') tensor([ 1,  5,  8,  3, 13,  0,  3, 13,  7,  4,  0,  0, 12, 13, 10,  1],
#        device='cuda:0')
# tensor([12,  3, 13,  3,  5, 11, 11,  7,  3,  5,  6,  7,  9, 12,  2,  0],
#        device='cuda:0') tensor([12,  3, 13,  7,  5,  9, 11,  3,  3,  5,  0,  7,  9,  9,  2,  6],
#        device='cuda:0')
# tensor([ 0,  7,  6,  5,  0,  7,  1,  1,  6, 11,  8, 12,  6, 11,  9, 11],
#        device='cuda:0') tensor([ 3,  7,  6,  5,  9,  7,  1,  1,  6, 11,  8, 12,  6, 11,  9, 12],
#        device='cuda:0')
# tensor([12, 10,  7, 10,  7,  6,  9,  1, 13, 13,  0,  9,  2,  8,  2,  8],
#        device='cuda:0') tensor([ 1, 10, 12, 10,  7,  6,  9,  1, 13, 13,  0, 11,  2,  8,  2,  8],
#        device='cuda:0')
# tensor([ 5,  8,  3,  9, 11, 11,  8,  2,  1,  9, 10,  0, 13,  8,  5,  9],
#        device='cuda:0') tensor([ 5, 10,  5,  9, 11, 11,  3,  2,  1,  3, 10,  0, 13,  8,  6,  0],
#        device='cuda:0')
# tensor([ 0,  8,  5, 11,  8, 12, 13,  1, 10,  7,  3,  7, 11, 12, 13,  8],
#        device='cuda:0') tensor([ 0,  9,  5, 11,  8, 12,  5,  1,  0,  7,  3,  3, 12, 12, 13,  8],
#        device='cuda:0')
# tensor([10,  8,  6, 11, 13, 10, 13, 12,  6,  7,  3,  1,  3,  3,  0,  1],
#        device='cuda:0') tensor([10,  8, 10, 11, 13, 10,  8, 12,  1,  7,  3, 12,  3,  3,  7,  1],
#        device='cuda:0')
# tensor([10,  3,  2, 10, 13,  8,  7, 10,  3,  3,  5, 12,  1,  8, 12,  1],
#        device='cuda:0') tensor([ 1,  3,  2, 10, 12,  8,  9,  8,  3,  3,  5, 12,  1,  8, 12,  1],
#        device='cuda:0')
# tensor([12,  9,  6, 11,  7, 12,  1,  3,  1,  0, 12,  6, 11, 13, 10, 12],
#        device='cuda:0') tensor([ 9,  9,  6, 11,  9,  9, 11,  3, 12,  0, 12,  9, 11, 13, 10, 12],
#        device='cuda:0')
# tensor([ 0, 13,  5,  0,  8,  2, 12,  3,  0,  2,  3,  1,  1, 12,  5,  7],
#        device='cuda:0') tensor([10, 13,  5,  0,  8,  2, 12,  3,  2,  7,  3, 11,  1, 12,  5,  7],
#        device='cuda:0')
# tensor([ 5,  7, 13,  0,  0,  6, 12,  9,  2,  0,  3,  1,  0, 13,  8,  6],
#        device='cuda:0') tensor([ 5,  7,  0,  1,  0,  6, 12,  9,  2,  0,  3,  1, 11, 11,  8,  9],
#        device='cuda:0')
# tensor([10, 10,  0,  2, 13,  1,  7,  1,  5, 13, 10,  8, 10, 10,  8,  1],
#        device='cuda:0') tensor([ 0,  6,  8,  2,  4,  1,  9,  1,  7, 13,  8,  8, 10,  6,  8,  0],
#        device='cuda:0')
# tensor([ 9,  7,  2,  7,  0,  8,  1,  2,  9,  3, 12,  9, 12,  0,  5,  6],
#        device='cuda:0') tensor([ 9,  7,  2, 11,  0,  2,  0,  2,  7,  3, 12, 11, 12,  0,  5,  2],
#        device='cuda:0')
# tensor([ 0,  1,  6,  6, 10,  9, 10,  1,  5, 11,  1, 10,  9,  1, 10,  8],
#        device='cuda:0') tensor([ 0,  1,  9,  6, 10,  9, 10,  1,  5, 11,  1, 10,  9,  1, 10,  8],
#        device='cuda:0')
# tensor([ 1, 13,  6,  5,  0,  5,  3,  1,  3, 13,  9, 10,  8,  5,  5,  2],
#        device='cuda:0') tensor([ 1, 13,  6,  5,  0,  5,  3,  1,  7, 13,  9, 10,  8,  5, 11,  2],
#        device='cuda:0')
# tensor([ 3, 13, 10,  6, 13,  0,  3,  0,  2,  0, 13,  8,  0, 13,  3,  6],
#        device='cuda:0') tensor([ 7, 13, 10,  6,  4,  0,  5,  0,  2,  6, 13,  6,  9, 13,  3,  6],
#        device='cuda:0')
# tensor([ 8, 10,  7, 11, 11,  1, 10,  3,  9,  8, 13, 12, 10, 13,  8, 11],
#        device='cuda:0') tensor([ 8,  5,  7,  1,  1,  8, 10,  6,  9,  2, 13, 12,  6, 13,  4, 11],
#        device='cuda:0')
# tensor([12, 10,  2, 12,  6,  9,  0,  6,  7,  9,  7,  8, 12, 13,  3, 12],
#        device='cuda:0') tensor([12,  1,  2, 12,  8,  0,  9,  6,  7,  8,  7,  6, 12, 13,  8, 12],
#        device='cuda:0')
# tensor([ 8, 13,  7,  2, 12, 11, 12,  9,  2,  3, 11, 11,  3,  9,  9, 12],
#        device='cuda:0') tensor([ 8,  2,  5,  2, 12, 12, 12,  9,  2, 11, 11,  2,  3,  9,  8,  6],
#        device='cuda:0')
# tensor([ 3,  3,  6,  3, 13,  7, 11,  3,  2, 12, 11,  6,  5,  1,  2, 13],
#        device='cuda:0') tensor([ 7,  5, 10,  3, 13,  7, 11,  2,  2, 12, 11, 10,  3,  1, 11, 13],
#        device='cuda:0')
# tensor([11,  7,  9,  9,  8,  2, 10,  9,  1, 12,  0,  5,  1,  8,  5,  0],
#        device='cuda:0') tensor([ 0,  7, 11, 11,  8,  2, 10,  7,  1, 12,  0,  5,  8,  8,  5, 10],
#        device='cuda:0')
# tensor([ 5, 11,  9,  7,  6,  2,  5, 12,  2, 10,  3, 12, 10,  0,  4,  8],
#        device='cuda:0') tensor([ 5, 11,  9,  7,  3,  2,  5, 12,  2, 12, 10, 12,  0,  6,  4,  8],
#        device='cuda:0')
# tensor([ 5,  0, 12, 13,  1, 10, 10,  7,  2,  9,  3,  9, 13,  6, 10,  5],
#        device='cuda:0') tensor([ 5,  0, 12, 13, 11,  0, 10,  7,  2,  1,  3,  9, 13,  0,  6,  3],
#        device='cuda:0')
# tensor([ 6, 12,  2,  6,  1,  3, 10,  2, 11, 13,  8, 12, 13,  6,  2, 13],
#        device='cuda:0') tensor([ 6,  1,  2,  6,  1,  3, 10,  2,  1, 13,  3,  1, 13,  1,  2, 13],
#        device='cuda:0')
# tensor([10,  3, 12, 10,  5,  3,  0,  6,  6, 12, 12, 10,  8,  2, 12,  1],
#        device='cuda:0') tensor([ 7,  3, 12, 10,  7,  3, 13, 12, 11,  2, 12, 10,  2,  8, 12, 11],
#        device='cuda:0')
# tensor([ 9,  9,  3,  9, 12,  7,  6,  5,  3,  5,  9,  8,  9, 10, 11,  7],
#        device='cuda:0') tensor([ 9,  9,  5,  6, 12,  7,  6,  3,  3,  5,  9,  8,  9, 10, 11,  7],
#        device='cuda:0')
# tensor([ 0,  2,  6,  8,  2, 12,  7,  4,  3, 13,  2,  1,  8,  1,  8,  6],
#        device='cuda:0') tensor([ 3,  2,  6,  8,  2, 12,  0,  8,  3,  5,  2,  1,  2,  9,  8,  6],
#        device='cuda:0')
# tensor([11,  7,  6,  2, 10,  9,  3,  7,  2,  6,  7,  7,  0,  8,  7,  6],
#        device='cuda:0') tensor([ 0,  7,  6,  2, 10,  9,  3,  7,  2,  6,  7,  3,  8,  8,  7,  1],
#        device='cuda:0')
# tensor([ 8,  9, 11, 12,  4,  6, 11,  8,  5, 10, 10,  7,  2, 13,  2,  6],
#        device='cuda:0') tensor([ 1,  9, 11, 12,  4,  0, 11,  8,  5,  6,  6,  7,  2, 13,  2,  6],
#        device='cuda:0')
# tensor([ 2,  5,  7,  5,  6,  7, 12,  8,  2, 13,  0, 11, 10,  2,  1, 12],
#        device='cuda:0') tensor([ 2,  5,  7,  7,  6,  7, 12,  8,  2,  5,  0, 11,  0, 13,  1, 12],
#        device='cuda:0')
# tensor([ 6,  5, 13, 13, 11,  7, 10, 10, 10,  2, 11, 12, 13, 11,  3, 13],
#        device='cuda:0') tensor([ 6,  5, 10, 13, 11,  7, 10, 10, 10,  2,  1, 11, 13, 11,  3, 13],
#        device='cuda:0')
# tensor([12, 13, 10, 13,  6, 12, 10,  5, 12,  9,  5,  8, 12,  7, 12,  7],
#        device='cuda:0') tensor([13, 13, 10, 13,  0, 12,  3, 13, 12,  9,  5,  4,  9,  7, 12,  7],
#        device='cuda:0')
# tensor([ 7,  8, 13, 10,  5, 13, 13,  1, 10,  9,  0,  7,  1,  6,  8,  7],
#        device='cuda:0') tensor([ 6,  8, 13, 10,  7, 13, 13,  1, 10,  9, 12,  7,  1,  6,  8,  7],
#        device='cuda:0')
# tensor([ 3,  0,  1,  5,  2, 13,  3,  7,  6,  3, 13,  0,  3, 13,  8,  7],
#        device='cuda:0') tensor([ 3,  0,  8,  5,  2, 13,  3,  3,  7,  0, 13,  1,  3, 13,  0,  5],
#        device='cuda:0')
# tensor([ 0,  9,  4,  8,  2, 12,  8,  9,  2,  3,  5,  8, 11,  5,  9, 13],
#        device='cuda:0') tensor([ 0,  9,  7,  0,  2, 12,  1,  9,  2,  7,  3,  8, 12,  5,  9,  7],
#        device='cuda:0')
# tensor([ 6, 12, 12, 12,  1, 12, 10, 13, 12,  8,  4, 13,  6,  3,  3,  8],
#        device='cuda:0') tensor([ 0, 12, 12, 12,  2, 12,  0, 13,  7,  8,  4, 13,  6,  5,  2,  8],
#        device='cuda:0')
# tensor([ 8,  3, 10,  0, 12, 13,  8,  1, 12, 13,  2,  8, 13,  2,  1,  2],
#        device='cuda:0') tensor([ 8,  5, 10,  0, 12, 12,  8,  9, 12, 11,  2,  8, 13,  3,  1,  2],
#        device='cuda:0')
# tensor([ 7,  6, 11,  2,  9,  5,  8,  5,  5,  8,  8, 11,  8,  5,  3,  5],
#        device='cuda:0') tensor([12,  6,  1, 13,  9,  5,  2,  5,  3,  2,  0, 11, 11,  5,  3,  7],
#        device='cuda:0')
# tensor([ 8,  2,  6, 11,  3,  2,  3,  8,  3,  3,  6,  8,  6, 10,  9, 11],
#        device='cuda:0') tensor([ 8,  2,  6, 11,  3,  2,  3,  9,  3,  3,  6,  8,  6, 10,  9, 12],
#        device='cuda:0')
# tensor([ 3,  9,  3, 13,  6,  2,  3, 10,  3, 12,  2, 12,  1,  9,  7,  1],
#        device='cuda:0') tensor([ 9,  1,  3, 13,  6,  2,  3,  8,  3, 12,  7,  2, 11,  9,  7,  1],
#        device='cuda:0')
# tensor([ 0,  7,  7,  7,  1, 12,  2, 11,  9,  7, 10,  6,  7, 13,  8,  2],
#        device='cuda:0') tensor([ 6,  7,  7,  7,  1, 12,  1, 11,  9,  7,  8,  6,  7,  9,  8,  2],
#        device='cuda:0')
# tensor([ 5,  5,  1,  5,  9,  1,  1, 12,  2,  1, 13,  6,  9,  7,  2,  8],
#        device='cuda:0') tensor([ 5,  3,  1,  5,  9,  1,  1,  5,  2,  1, 13, 10,  9,  7,  2,  8],
#        device='cuda:0')
# tensor([ 5,  6, 10,  5,  2, 11,  8,  2,  6, 11,  5, 13, 11,  8,  2,  9],
#        device='cuda:0') tensor([ 5,  0, 10,  5,  1, 11,  2,  2, 10, 11,  5,  6, 11,  9,  2,  9],
#        device='cuda:0')
# tensor([ 5,  2,  7,  9,  3,  6,  5,  5,  1,  9,  0,  3, 13,  8,  9, 13],
#        device='cuda:0') tensor([ 5,  2,  7, 11,  7,  7,  3,  4,  1,  9,  0,  3, 13, 11,  0, 13],
#        device='cuda:0')
# tensor([ 6,  8, 11,  2,  9,  8,  7,  8,  3,  8, 10, 11,  9,  8,  6,  6],
#        device='cuda:0') tensor([ 9,  8,  4,  3, 12,  6,  7,  8,  3, 11,  6, 11,  9,  3, 10,  8],
#        device='cuda:0')
# tensor([11, 10, 13,  6, 13,  8,  0,  8, 11,  6, 13, 10, 11,  3, 10,  3],
#        device='cuda:0') tensor([11, 10,  8,  6, 12,  8,  0,  8, 11,  6, 13,  6, 11,  7, 10, 10],
#        device='cuda:0')
# tensor([ 8,  4,  5,  6,  3,  6,  6,  2,  3, 10,  9,  6,  7, 13,  5,  3],
#        device='cuda:0') tensor([ 8,  3,  5,  6,  5,  8,  6,  2,  3, 10,  9,  6,  3, 13,  7,  5],
#        device='cuda:0')
# tensor([ 4, 13,  1,  7, 12, 13,  9,  2, 11, 12, 10,  0,  6,  9,  5,  0],
#        device='cuda:0') tensor([ 4, 13,  1,  7, 12, 13,  9,  2, 11, 12, 10,  0, 10,  9,  3,  6],
#        device='cuda:0')
# tensor([ 5, 12,  7, 11,  7,  9, 11,  0,  9,  0,  0, 13, 13,  3, 13,  6],
#        device='cuda:0') tensor([ 5,  8,  7, 11,  7,  9, 11,  8,  9, 10,  4,  0,  8,  3,  8,  6],
#        device='cuda:0')
# tensor([ 1,  8,  3,  2,  5, 13, 11, 12, 11,  0,  8,  2,  2,  9,  9,  7],
#        device='cuda:0') tensor([ 1, 12,  7,  2,  5, 12, 11, 12, 11,  0,  8,  2,  2,  9,  9,  7],
#        device='cuda:0')
# tensor([ 6, 10, 10, 13,  7,  0,  7,  2,  4, 10,  2, 10, 12,  1,  2,  5],
#        device='cuda:0') tensor([10, 10,  8, 12,  7,  0,  7,  2,  4, 10,  2, 10, 12,  1,  2,  5],
#        device='cuda:0')
# tensor([13, 13,  5,  0, 10,  1, 13,  8, 13,  5,  9,  3,  1,  7,  0, 12],
#        device='cuda:0') tensor([13, 13,  3,  0, 10,  1, 13,  8, 13,  1,  9,  3,  1,  7,  0, 12],
#        device='cuda:0')
# tensor([ 0, 12,  5,  8,  2,  5,  2,  2,  1,  7, 12,  3, 10,  2, 13, 13],
#        device='cuda:0') tensor([ 2,  0,  5,  8,  2,  3, 12,  2,  1,  7, 12, 10, 10,  2, 13, 13],
#        device='cuda:0')
# tensor([ 7,  8,  2,  3, 11,  7,  7, 13, 12,  2,  7, 11,  1,  5,  7,  8],
#        device='cuda:0') tensor([ 3,  8,  2,  3, 11, 13,  7, 13, 12,  8,  7,  1,  1,  5,  7,  8],
#        device='cuda:0')
# tensor([13, 13, 10,  3,  0, 12,  1,  7,  7, 13,  3,  5, 11,  9, 13, 10],
#        device='cuda:0') tensor([13, 13, 10, 11,  0, 12,  9,  7,  7, 12,  3,  5,  9,  9, 13,  0],
#        device='cuda:0')
# tensor([12,  6,  3,  0, 10,  0,  2, 11,  1,  7,  8, 13,  5,  7,  2,  1],
#        device='cuda:0') tensor([12, 11,  7,  0, 10,  0,  2, 11,  1,  7,  1, 12,  9,  5,  2,  2],
#        device='cuda:0')
# tensor([ 9,  3,  3, 10,  3,  5,  7,  3,  2,  3,  2,  4, 13, 13,  1,  0],
#        device='cuda:0') tensor([ 1,  7,  7, 10,  5,  3,  7,  3, 10,  3,  2,  4, 13, 13,  1,  6],
#        device='cuda:0')
# tensor([ 7,  6,  5, 13, 12,  6,  0,  3,  8,  0,  1,  6, 13,  2,  6, 10],
#        device='cuda:0') tensor([ 7,  6,  5, 13, 12, 12,  0,  3,  8,  0,  9,  6, 13,  2,  8, 10],
#        device='cuda:0')
# tensor([11,  5,  4,  9, 13, 10, 10,  9,  1,  3,  5,  0,  0,  2, 12, 12],
#        device='cuda:0') tensor([ 1,  5,  1,  9, 12,  0,  8,  9,  1,  1,  5,  0,  9,  8,  2, 12],
#        device='cuda:0')
# tensor([10,  7,  7,  0,  7,  8,  3, 13, 13,  3,  9, 13,  1,  7,  2,  7],
#        device='cuda:0') tensor([10,  5,  7,  6,  7,  8,  7, 11, 13,  7,  7, 13,  2,  3,  2,  2],
#        device='cuda:0')
# tensor([12, 13, 11, 12,  7, 13,  9,  1,  7,  1,  1,  7, 11, 13,  7,  3],
#        device='cuda:0') tensor([12, 13,  2, 13,  7, 13, 11,  3,  3,  1,  1,  7, 11,  7,  3,  3],
#        device='cuda:0')
# tensor([ 3,  3,  6,  7,  9, 10, 13,  6,  1,  1,  8, 13, 10,  0,  3,  2],
#        device='cuda:0') tensor([ 9,  8,  9,  7,  7,  6, 13,  6,  1, 11,  8, 13,  0,  0,  7,  2],
#        device='cuda:0')
# tensor([ 2,  4, 12,  7,  3,  9,  2,  8, 12,  3,  7, 10, 11, 11,  7,  8],
#        device='cuda:0') tensor([ 2,  4, 12,  3,  6, 12,  2,  8,  2,  2, 10, 10, 11, 11,  7,  0],
#        device='cuda:0')
# tensor([ 0,  5,  2,  7,  1,  1,  2, 13,  7,  9, 10,  5,  5, 12,  1, 13],
#        device='cuda:0') tensor([ 9,  3, 13,  7,  1,  1,  3, 13,  7,  9, 10,  5,  5, 11, 11, 13],
#        device='cuda:0')
# tensor([ 3,  8,  3,  6,  3, 10,  8,  6,  3, 13,  7,  1,  3,  2,  9, 13],
#        device='cuda:0') tensor([ 3,  0,  7,  6,  1, 10,  8,  9,  6,  3,  7,  1,  3,  4,  9, 13],
#        device='cuda:0')
# tensor([ 1,  5, 13, 12,  9,  1,  3,  0,  3,  4,  3,  5,  1,  5,  1, 11],
#        device='cuda:0') tensor([ 2,  5, 13, 12,  0,  1,  3,  6,  5, 12,  5,  5,  9,  7, 11, 11],
#        device='cuda:0')
# tensor([10,  3,  8, 13, 13,  6, 12, 12, 13, 10,  6,  9,  3,  8,  2,  3],
#        device='cuda:0') tensor([10,  3,  2, 13, 13,  9, 12, 12, 13, 10,  6,  2,  3,  8,  2,  3],
#        device='cuda:0')
# tensor([ 7, 13,  6,  3, 11,  0,  8,  9,  8,  6,  1, 10, 10,  9,  3, 10],
#        device='cuda:0') tensor([ 7, 13,  6, 10,  9,  6,  8,  9,  7,  6,  1,  6,  6,  9, 10, 10],
#        device='cuda:0')
# tensor([ 9, 10, 10, 11,  6,  0, 12, 12, 12,  5, 13, 11,  6,  8,  7,  9],
#        device='cuda:0') tensor([ 9,  6,  8, 11,  6, 10, 12, 12, 11,  5, 13,  9,  6,  8,  7,  9],
#        device='cuda:0')
# tensor([ 9, 10,  0, 10,  9,  3,  5,  8, 13, 13, 12,  8,  5,  8,  0, 11],
#        device='cuda:0') tensor([ 9, 10,  5, 10,  9,  3,  5,  8,  8,  8,  4,  2,  4,  8,  0,  6],
#        device='cuda:0')
# tensor([ 7,  5, 13,  6,  5,  0,  5,  7, 10, 10,  2,  9,  8, 11,  3, 13],
#        device='cuda:0') tensor([ 7,  3, 13, 11,  5,  8,  3,  7, 10, 10,  2,  6, 10, 11,  3, 11],
#        device='cuda:0')
# tensor([ 9, 12,  9,  7,  8,  0, 12,  3,  3,  1, 13,  7,  1,  3,  0, 11],
#        device='cuda:0') tensor([ 8, 12,  8,  7,  3, 10, 11,  3,  9,  1,  3,  7,  1,  3,  0, 11],
#        device='cuda:0')
# tensor([10,  5, 11,  3, 12, 13,  5,  3,  9, 10, 12,  8,  7,  9,  3,  9],
#        device='cuda:0') tensor([ 6,  5,  0, 12, 12,  5,  5,  3,  9, 10, 12,  8,  3,  8,  7,  9],
#        device='cuda:0')
# tensor([ 2,  3,  1,  5,  1, 11,  8, 11,  3,  2,  5,  6,  2, 12,  9,  3],
#        device='cuda:0') tensor([ 2,  3,  1,  5,  1,  6,  6, 11,  3,  2,  5,  8,  7, 12,  9,  3],
#        device='cuda:0')
# tensor([ 3,  2,  8, 12,  1,  0,  0,  5,  9,  3, 13,  3,  5,  3,  6,  1],
#        device='cuda:0') tensor([ 5,  3,  8, 12, 13,  0,  6,  5,  9,  3, 13,  3,  5,  7,  6,  1],
#        device='cuda:0')
# tensor([ 0,  0, 13,  6,  7,  8,  8,  8,  3,  3,  7, 13,  2, 11,  3,  8],
#        device='cuda:0') tensor([ 0,  0, 13,  6,  7,  1,  8,  2,  0,  3,  7, 13,  2, 11,  0,  8],
#        device='cuda:0')
# tensor([ 2,  9,  5,  8, 11,  3,  2,  3,  8,  7, 11, 12,  3,  9, 10,  9],
#        device='cuda:0') tensor([ 2,  9,  5,  8, 11, 12,  2,  3,  0, 12, 11, 11,  7,  9, 10,  9],
#        device='cuda:0')
# tensor([11,  5,  8,  3,  3,  7,  2,  1,  9,  4,  1,  2,  5,  3, 12,  8],
#        device='cuda:0') tensor([11,  5,  8,  7,  3,  3,  2,  0,  9,  4,  1,  2,  5,  3, 11,  8],
#        device='cuda:0')
# tensor([ 5,  3,  3,  6,  9,  9,  3, 13,  3,  3, 10,  1, 12,  4, 11, 10],
#        device='cuda:0') tensor([ 5,  1,  5,  6,  9,  9,  3, 13,  3,  3, 10,  1, 12,  4, 11, 10],
#        device='cuda:0')
# tensor([11, 13, 13,  3,  0, 13,  8, 10,  8,  1,  8,  0,  7,  3,  6, 13],
#        device='cuda:0') tensor([11, 13, 13,  3,  0, 13,  3,  6,  8, 11,  8,  0,  7, 12,  6, 13],
#        device='cuda:0')
# tensor([ 3,  5,  2,  5,  3,  9,  2,  7, 13,  9,  2,  5,  0,  9, 13, 11],
#        device='cuda:0') tensor([ 5,  5,  3,  5,  3,  9,  2,  7, 13,  9,  2,  3,  8,  0, 13,  9],
#        device='cuda:0')
# tensor([ 7,  6,  9,  8,  7,  3, 13,  8, 11,  5,  0,  6,  9,  5,  3,  5],
#        device='cuda:0') tensor([ 7,  6,  9,  8,  3, 12, 11,  8, 11,  5,  6,  0,  9,  7,  9,  5],
#        device='cuda:0')
# tensor([ 1,  4,  6,  0,  5, 13,  2, 11,  7,  8,  6,  3, 11, 10, 10, 10],
#        device='cuda:0') tensor([ 1,  4,  0,  0,  5, 13,  1, 11,  7,  8,  6,  5,  9,  8, 10, 10],
#        device='cuda:0')
# tensor([12,  9, 10, 13, 12,  8,  3,  0, 12,  6, 10,  5, 10,  3,  6,  7],
#        device='cuda:0') tensor([ 6, 11,  6, 13, 12,  8,  2,  6,  2,  6, 10,  5, 10,  5,  0,  7],
#        device='cuda:0')
# tensor([ 8, 13, 11,  9,  0,  1,  2, 10, 10,  0, 12,  7,  0,  6, 13,  8],
#        device='cuda:0') tensor([ 1, 11, 11,  9,  0,  1,  2, 10,  0,  0, 12,  7,  0,  9, 13,  8],
#        device='cuda:0')
# tensor([ 1,  2,  3,  9,  2, 11,  7,  9, 11,  2, 10,  1,  3, 12,  6, 11],
#        device='cuda:0') tensor([11,  2,  3,  9,  2, 11,  7,  6, 11,  2, 10,  1,  3, 12,  6, 11],
#        device='cuda:0')
# tensor([ 9,  1,  1, 13, 13,  5,  3,  0,  3,  6,  0, 10,  0,  3,  3, 12],
#        device='cuda:0') tensor([ 7,  9,  1, 13, 13,  5,  7,  0,  3,  6,  6, 10,  0,  3,  5, 12],
#        device='cuda:0')
# tensor([ 6,  7,  6,  9,  6,  6,  1, 10, 10, 11,  0,  6,  7, 10,  9,  2],
#        device='cuda:0') tensor([ 6,  7,  6,  2,  6,  0,  1, 10, 10, 11,  0,  0,  7, 10,  6,  1],
#        device='cuda:0')
# tensor([ 3, 12,  5,  1,  2,  5,  3,  3,  9,  3,  9, 11,  1,  9,  2,  7],
#        device='cuda:0') tensor([ 5, 12,  5,  1,  2,  5,  3,  3,  9,  7,  7, 11,  1,  9,  2,  7],
#        device='cuda:0')
# tensor([ 2,  3, 11, 13,  8, 13,  7,  6,  5,  2,  0, 10,  3,  7, 10, 12],
#        device='cuda:0') tensor([ 8,  7, 11,  2,  8, 13,  7,  6,  3,  2,  0,  8,  3,  7, 10, 12],
#        device='cuda:0')
# tensor([ 2,  6,  8,  9, 10,  1,  8, 10,  8, 13, 10,  9,  3,  9,  7,  1],
#        device='cuda:0') tensor([ 2,  6,  8,  9,  6,  7,  8, 10,  8, 13, 12,  9,  4,  1,  7,  1],
#        device='cuda:0')
# tensor([ 6, 13,  6,  5,  0, 11,  6,  7, 13, 13,  1, 12,  0, 13, 13, 11],
#        device='cuda:0') tensor([ 6,  2,  6,  5,  0,  2,  0,  4, 13, 13,  1, 12, 11, 13, 13, 11],
#        device='cuda:0')
# tensor([10,  6,  7,  6,  2,  8,  2,  0,  9, 12, 13,  8,  8,  5,  0, 13],
#        device='cuda:0') tensor([10,  6,  7,  0,  2,  8, 12,  0,  9,  6, 13,  0,  8,  7,  0, 13],
#        device='cuda:0')
# tensor([11,  7, 13, 10, 12,  2, 10, 13,  1,  0,  1,  9,  7,  2, 11,  0],
#        device='cuda:0') tensor([ 1,  7, 13,  0, 12,  2, 10, 13, 12,  6, 11,  0,  7,  2, 11, 10],
#        device='cuda:0')
# tensor([13,  0,  0,  5,  9,  5,  8,  1, 12,  8,  0,  8,  2, 11,  3,  9],
#        device='cuda:0') tensor([13,  9,  0,  3,  9,  5, 10, 11, 12,  8,  5,  0,  2,  9,  5,  9],
#        device='cuda:0')
# tensor([ 2, 10,  9,  2, 13, 10, 11,  0,  0,  8,  0,  8, 12,  2,  7,  5],
#        device='cuda:0') tensor([ 2,  8,  9,  2, 13, 10,  1, 10,  0,  1,  6,  8, 12,  1,  7,  5],
#        device='cuda:0')
# tensor([ 3,  7,  4,  2,  9, 13, 13, 13,  8,  5, 10,  2,  7,  8, 13,  9],
#        device='cuda:0') tensor([ 3,  7,  9,  2,  9, 13, 13,  8,  8,  3, 10,  5,  7,  8,  7,  9],
#        device='cuda:0')
# tensor([10,  6, 12, 11,  1, 12,  5,  7,  1, 12,  0,  0, 11,  7, 11,  5],
#        device='cuda:0') tensor([ 6,  0,  5, 11, 12, 12,  2,  3,  1, 12,  0,  0, 11,  7, 13,  5],
#        device='cuda:0')
# tensor([11, 10,  1,  3,  9,  9, 12,  2, 10,  8,  8, 12, 10, 10,  0,  2],
#        device='cuda:0') tensor([12, 10,  1,  7,  1, 10, 12, 13, 10,  8,  8,  1, 10, 10,  0,  1],
#        device='cuda:0')
# tensor([12, 12,  1,  2, 10,  3, 11,  9,  7,  2,  2,  6,  6,  6, 12,  0],
#        device='cuda:0') tensor([12, 12,  1,  2, 10,  3, 11,  9,  3,  2,  2, 10,  6,  6, 12,  0],
#        device='cuda:0')
# tensor([10,  7, 10, 10,  0,  3,  7,  0,  3, 10, 12, 10,  7,  7,  6,  7],
#        device='cuda:0') tensor([ 6,  7, 13, 10, 12,  3, 11,  0,  3,  0, 12, 10,  7,  7,  6,  7],
#        device='cuda:0')
# tensor([ 5,  5, 10,  0,  0, 13,  3, 13,  0,  8,  7,  5, 10, 10,  5,  9],
#        device='cuda:0') tensor([ 5,  5, 10, 11,  0,  7,  5, 13, 10,  9,  5,  3, 10, 10,  4, 11],
#        device='cuda:0')
# tensor([ 7,  6, 10,  7,  8,  1, 11,  5,  7, 10,  2,  0,  5,  3,  7, 10],
#        device='cuda:0') tensor([ 5,  6,  2,  7,  8,  1, 11,  5,  7,  3,  2,  0,  5,  5,  7, 10],
#        device='cuda:0')
# tensor([ 5, 10,  9,  0, 11,  0,  3, 12,  3,  9, 13,  0,  2,  6,  8,  6],
#        device='cuda:0') tensor([ 5, 10,  9,  9,  1,  6,  3, 12,  3,  9, 13,  0,  0,  9,  6,  0],
#        device='cuda:0')
# tensor([ 0,  3, 10, 13,  1,  8,  5,  1, 13, 10,  2,  6, 12,  3,  7, 12],
#        device='cuda:0') tensor([ 0,  3,  0, 13,  1,  2,  5,  1, 11,  9,  2, 10, 12,  4,  7,  3],
#        device='cuda:0')
# tensor([ 7,  2, 11,  8,  6,  2,  3,  1, 12, 10,  2,  9,  1, 11, 12,  8],
#        device='cuda:0') tensor([ 3,  3,  1,  8,  6,  2,  3,  1, 12,  6,  2,  1, 12, 11, 12,  8],
#        device='cuda:0')
# tensor([10,  7,  8,  2,  6, 12,  7,  8,  0, 13,  1,  5,  5, 10,  6,  7],
#        device='cuda:0') tensor([10,  7,  8,  2,  9, 12,  7,  8,  0, 13,  1,  5,  5, 10,  9,  2],
#        device='cuda:0')
# tensor([13, 13,  2, 10,  0,  7, 10,  8, 10,  1,  2, 10, 11, 13,  7,  7],
#        device='cuda:0') tensor([13, 13,  2, 10,  6,  7, 10,  8, 10,  1,  1, 10, 11, 13,  7,  7],
#        device='cuda:0')
# tensor([13,  7,  1,  5,  1, 13,  6,  3,  5, 12,  6, 10,  5, 12,  7,  7],
#        device='cuda:0') tensor([13,  7,  1,  5,  9, 13,  6,  3,  5, 12,  6,  0,  5, 12,  3,  7],
#        device='cuda:0')
# tensor([ 0,  8,  9,  3, 11,  1,  4, 10,  0,  2,  1,  0,  7,  0, 10, 13],
#        device='cuda:0') tensor([ 0,  8,  1,  8, 11,  1,  2, 10,  6,  2, 11,  0,  7,  9,  6, 13],
#        device='cuda:0')
# tensor([ 5,  7,  1, 10,  0, 12,  2,  6,  7,  2,  6,  2, 12, 12,  0, 11],
#        device='cuda:0') tensor([ 5,  3,  1, 10,  0,  8, 13,  0,  3,  6,  1, 11, 12, 12,  1, 11],
#        device='cuda:0')
# tensor([ 7,  1,  8, 12,  3,  1, 11,  1, 11, 11,  5,  1, 13, 13,  2,  3],
#        device='cuda:0') tensor([ 7,  2,  8,  2, 11, 12,  3,  1, 11, 11,  5,  7, 13,  3,  2,  8],
#        device='cuda:0')
# tensor([ 1,  2,  7, 13,  9,  2, 13,  2, 10, 10,  5,  6,  5,  7, 13, 12],
#        device='cuda:0') tensor([ 1,  2,  3, 11,  6, 13, 13,  2,  6, 10,  5,  1,  3,  3, 13, 12],
#        device='cuda:0')
# tensor([11, 13,  2,  0,  8,  4,  1,  7,  3,  8,  0,  0,  2,  0, 10,  3],
#        device='cuda:0') tensor([ 0, 13, 12,  6,  8,  4,  1,  7,  3,  8,  9,  0,  8,  8, 10,  3],
#        device='cuda:0')
# tensor([ 3,  1, 13,  5,  8, 12,  6,  9,  6,  7,  7,  1,  8, 10, 12,  7],
#        device='cuda:0') tensor([ 7, 11,  0,  3,  2,  6, 10,  0,  6,  9,  7,  1,  8, 10, 12,  7],
#        device='cuda:0')
# tensor([ 7, 10,  3,  0,  0,  1,  4, 12, 10,  0,  8,  2,  9,  3,  0,  7],
#        device='cuda:0') tensor([ 3, 10,  3,  0, 11,  1,  4, 12, 10,  1,  8,  2,  7,  5,  0,  7],
#        device='cuda:0')
# tensor([12,  0, 13,  6,  9, 10, 13,  2,  5,  2,  8, 10, 10,  2,  0, 11],
#        device='cuda:0') tensor([12,  0, 13,  6,  6,  0,  3,  2,  5,  8,  8,  0, 10,  2,  0, 13],
#        device='cuda:0')
# tensor([ 5, 11,  5,  3, 10,  7,  8,  2,  7,  3, 13,  3, 12,  3,  5,  2],
#        device='cuda:0') tensor([ 5,  7,  3,  7, 10,  5,  8,  2,  7,  1, 12,  9, 12,  3,  4,  2],
#        device='cuda:0')
# tensor([ 3, 12,  6, 12,  0, 12,  3,  1,  0,  5, 10, 12,  4,  9,  3,  5],
#        device='cuda:0') tensor([ 5,  7,  6, 12,  1, 12,  2, 12, 10,  5,  8, 12,  4,  9,  7,  5],
#        device='cuda:0')
# tensor([13,  8,  2,  5, 12,  3,  7,  7,  6,  7, 12, 13, 10, 13,  5,  3],
#        device='cuda:0') tensor([13,  8, 13,  5, 11,  3,  7,  7,  6,  7, 12, 13, 10, 11,  5,  3],
#        device='cuda:0')
# tensor([ 7, 10, 13,  0, 10,  6,  3,  4,  3, 13,  7,  3,  6, 11, 11,  7],
#        device='cuda:0') tensor([ 7, 10, 13,  0, 10,  6,  5,  4,  7, 13,  7,  7,  6, 11,  0,  7],
#        device='cuda:0')
# tensor([ 7,  0,  2,  8,  3,  6,  9,  9, 12,  3, 11, 13,  2, 13, 12,  8],
#        device='cuda:0') tensor([ 3, 11,  2, 10,  7,  6,  9,  9, 11,  5, 11, 13,  2, 13, 12,  8],
#        device='cuda:0')
# tensor([ 6,  6,  0,  9, 11, 11, 11,  7,  1,  1,  2,  6, 13, 11,  6,  3],
#        device='cuda:0') tensor([10,  9,  0,  8, 11,  4, 11,  3,  1,  1,  2,  8, 13,  0,  6,  3],
#        device='cuda:0')
# tensor([ 1,  2, 12, 10, 10, 13, 13, 11,  4, 10, 11,  5,  0, 13,  1,  9],
#        device='cuda:0') tensor([ 9,  2, 12, 10, 10, 12, 13,  8,  4, 10, 11,  5,  1, 13, 12,  9],
#        device='cuda:0')
# tensor([ 6,  8, 11,  8,  3,  8,  8, 11,  8, 11,  2,  5, 12,  8,  9,  0],
#        device='cuda:0') tensor([ 6,  8,  8,  8,  3,  8,  8,  7,  8, 11,  2,  8, 12,  8,  0,  0],
#        device='cuda:0')
# tensor([13,  3, 13,  8,  3, 12,  2,  9,  5,  1,  9,  9, 12,  3,  3,  5],
#        device='cuda:0') tensor([13,  5,  9,  0,  3, 12,  2,  9,  5,  1,  9, 11, 12,  3,  5,  5],
#        device='cuda:0')
# tensor([ 5,  7,  0, 12, 12,  2, 11, 13,  8, 13,  8, 11,  8, 12, 11, 12],
#        device='cuda:0') tensor([ 5,  7,  0, 12, 13,  2, 11, 13,  8,  2,  8, 11,  8,  8, 11, 11],
#        device='cuda:0')
# tensor([ 3, 10,  4,  5,  1,  3,  3, 10,  2,  5,  2,  0,  7,  5,  1,  7],
#        device='cuda:0') tensor([ 3, 11,  4,  8,  1,  3,  3, 10,  2,  5, 12,  0,  7,  5,  1,  3],
#        device='cuda:0')
# tensor([ 3,  8,  0, 13,  5,  0,  8, 13,  3, 11,  2,  1,  5, 11, 13,  8],
#        device='cuda:0') tensor([ 3,  8,  0, 12,  3,  0,  9, 13,  3, 11,  2,  1,  7,  1, 13,  9],
#        device='cuda:0')
# tensor([ 3, 12,  3,  1,  8,  3, 13, 12,  3,  5, 12,  7, 13, 10,  7, 10],
#        device='cuda:0') tensor([ 3, 12,  3,  1,  8,  4,  2, 12,  3,  5, 12,  7, 13, 10,  5, 10],
#        device='cuda:0')
# tensor([12,  6, 12,  6,  7,  3,  7,  9, 13,  7,  9,  3,  8,  6, 12, 13],
#        device='cuda:0') tensor([12,  6, 12,  0,  3,  3,  4,  9, 13,  3,  9,  7, 10,  9, 12,  3],
#        device='cuda:0')
# tensor([12,  2,  2,  0,  7,  0, 11, 12,  1,  5, 11,  6, 10,  3,  6, 10],
#        device='cuda:0') tensor([12,  1,  3,  0,  0,  0, 11, 12,  1,  5, 11,  6, 10,  3,  4, 10],
#        device='cuda:0')
# tensor([ 3,  5,  0, 10,  9,  2,  0, 13,  6,  8,  5,  9, 13,  9,  5, 13],
#        device='cuda:0') tensor([ 7,  5,  6, 10,  9,  2,  0, 13, 10,  8,  5,  9, 13,  9,  3,  8],
#        device='cuda:0')
# tensor([ 7, 11, 12,  9, 11,  8, 13,  3, 12,  3,  3, 10,  1, 10, 12,  9],
#        device='cuda:0') tensor([ 7, 11, 12,  9, 11, 10,  2,  3, 12,  0,  7,  0,  1, 10,  2,  9],
#        device='cuda:0')
# tensor([ 6,  8,  5, 13,  5,  1, 12,  9,  1, 13,  8,  2, 10,  0,  2, 10],
#        device='cuda:0') tensor([ 6,  8,  5, 13,  2,  8, 12,  9,  1, 13,  8,  2,  6,  9,  2,  7],
#        device='cuda:0')
# tensor([ 6, 13,  8,  5,  0, 10, 12, 12,  9, 12,  1,  3,  3,  9, 10, 10],
#        device='cuda:0') tensor([10, 13,  8,  5,  0, 10, 12, 12,  1, 12,  1,  3,  3,  9, 10, 10],
#        device='cuda:0')
# tensor([ 6,  1,  5,  7, 11,  6,  3,  3, 10,  9,  0,  1, 13,  0,  0,  6],
#        device='cuda:0') tensor([ 2,  1,  5,  3, 11,  6,  7,  3, 10,  9, 10,  1, 13, 10, 10,  0],
#        device='cuda:0')
# tensor([10,  6,  7, 13, 11,  2,  9, 12,  7, 11,  2, 12, 11,  9, 10, 13],
#        device='cuda:0') tensor([10,  6,  7, 13,  2,  2,  6,  2,  7, 11,  2, 12, 13,  0,  6,  9],
#        device='cuda:0')
# tensor([13,  3,  8,  0,  3,  3,  3,  6,  0, 12, 12,  5, 11,  1,  2,  2],
#        device='cuda:0') tensor([13,  3,  8, 12,  3,  3,  5,  9,  0,  9, 12,  5,  1,  1, 11,  3],
#        device='cuda:0')
# tensor([ 7,  5,  5,  0, 13, 12,  0, 11,  3,  0,  7,  0, 12, 10,  6, 13],
#        device='cuda:0') tensor([ 7,  7,  5,  6, 13, 12,  0, 11,  3,  1,  3, 10, 12,  6,  0,  2],
#        device='cuda:0')
# tensor([ 3, 12,  3, 10,  8,  9,  2,  8,  0,  2,  5,  0, 13, 13,  7,  6],
#        device='cuda:0') tensor([ 0, 13,  3, 10,  8, 10,  2,  8,  0,  8,  5,  9, 13, 13,  3,  6],
#        device='cuda:0')
# tensor([ 2,  7, 13,  7,  3,  5,  9, 10,  3, 13, 10,  3,  8,  3, 10, 13],
#        device='cuda:0') tensor([ 0,  7,  1,  7,  3,  3,  9, 10,  3, 13, 10,  3,  8,  3,  6,  5],
#        device='cuda:0')
# tensor([13,  1,  2,  0, 13, 13,  5,  3, 13, 10,  0,  3,  9,  5, 10, 11],
#        device='cuda:0') tensor([ 2, 11, 10,  0,  1,  1, 12,  7, 13, 10,  0,  3,  7,  5, 10,  9],
#        device='cuda:0')
# tensor([11,  1, 12, 10,  9, 12,  5,  2,  6,  6, 11,  2,  6,  3,  5,  9],
#        device='cuda:0') tensor([11,  0, 12, 10,  9, 12,  5,  2,  7,  6,  9,  2,  6,  3,  5,  9],
#        device='cuda:0')
# tensor([12, 11, 11,  8, 11,  8, 10, 12,  1,  1, 10, 13, 13, 12,  0,  3],
#        device='cuda:0') tensor([12, 11, 11,  8, 11,  8, 10, 12,  2,  1,  0, 13,  8, 12,  0,  3],
#        device='cuda:0')
# tensor([11,  5,  3,  8,  8,  0,  5, 10,  8,  9, 11,  3, 10,  7,  1, 12],
#        device='cuda:0') tensor([11,  5,  2,  8,  8,  0,  3, 10,  8,  0, 12,  3,  4,  7,  1, 12],
#        device='cuda:0')
# tensor([ 6, 13,  5,  9, 13,  3,  0, 12,  1,  1, 12,  0,  4,  0,  1,  8],
#        device='cuda:0') tensor([ 6,  2,  5,  9, 13,  6,  0,  6,  1,  1, 12,  0,  7,  0, 13,  8],
#        device='cuda:0')
# tensor([ 3, 10,  3, 13,  3,  6,  2,  0, 12,  8,  5,  1,  1,  7, 11,  9],
#        device='cuda:0') tensor([ 3, 10,  3, 13,  5,  6,  2, 10,  9,  8,  3,  1,  1,  7, 13,  9],
#        device='cuda:0')
# tensor([ 1, 13,  7,  7,  5,  4, 12,  3,  5,  8,  5, 11,  5, 11,  3,  5],
#        device='cuda:0') tensor([ 2,  2,  7,  3,  8,  4, 12,  7,  5,  8,  5, 11,  5, 11,  5,  7],
#        device='cuda:0')
# tensor([10, 13, 11,  0, 12,  9,  7,  0,  8, 13, 13,  7, 12,  1,  1,  7],
#        device='cuda:0') tensor([10, 12, 11,  0, 12, 11,  7,  9,  8, 13, 13,  9, 11,  1,  1,  1],
#        device='cuda:0')
# tensor([ 0,  4,  7, 11, 13,  1, 12,  1, 13,  2, 10,  0,  0,  8,  7,  3],
#        device='cuda:0') tensor([ 0,  4,  7, 11, 13,  1, 12, 11, 13,  2, 10,  0,  0,  8,  7,  8],
#        device='cuda:0')
# tensor([13,  6,  6,  8,  9,  0,  5,  0,  5,  3, 12,  7,  6,  6,  5,  8],
#        device='cuda:0') tensor([13, 10,  6,  3,  6,  0,  5, 10,  5,  3, 12, 12,  6,  6,  3,  9],
#        device='cuda:0')
# tensor([ 7,  3,  7, 13,  2,  2, 12,  6,  8,  5,  3,  3, 13,  9,  7, 10],
#        device='cuda:0') tensor([ 7,  5,  7, 12, 13,  2, 12,  6, 10,  5,  3,  2,  1,  6,  7, 10],
#        device='cuda:0')
# tensor([ 3,  3,  1, 11,  5,  9, 11, 11, 13,  2,  9,  1, 10, 11,  3,  6],
#        device='cuda:0') tensor([ 5,  7,  9, 11, 11,  9, 11, 11, 13,  2,  9,  1,  6,  6,  3,  6],
#        device='cuda:0')
# tensor([10,  5,  7,  1,  1, 13,  5,  3, 10,  2, 13,  6, 10,  8,  5, 12],
#        device='cuda:0') tensor([10,  5,  7,  2,  1, 12,  5,  3, 10,  2, 13,  0, 12,  8,  0, 12],
#        device='cuda:0')
# tensor([ 3,  9,  1,  3,  1,  7, 10,  1, 11,  2,  1, 11,  6, 11, 10,  5],
#        device='cuda:0') tensor([ 3,  9,  1,  5,  1,  7, 10,  1,  1,  2,  1, 11,  9,  6, 10,  5],
#        device='cuda:0')
# tensor([ 0,  8,  3,  3,  6, 11,  7,  7, 11,  1, 10,  3,  0, 13,  9,  7],
#        device='cuda:0') tensor([ 0,  8,  3,  3, 10, 11,  4,  7,  0,  1, 10,  3, 11,  5,  9,  7],
#        device='cuda:0')
# tensor([12,  9,  3, 13,  6, 13,  5,  1,  0,  8, 11,  0,  0,  2,  0,  3],
#        device='cuda:0') tensor([12,  9,  3, 13,  9,  5, 11, 11,  0,  8,  9,  8,  0,  1,  0,  5],
#        device='cuda:0')
# tensor([10,  7, 10,  5,  3,  5,  5,  7,  1,  5,  2,  3,  6,  6,  1,  5],
#        device='cuda:0') tensor([ 8,  7,  0,  3,  3,  5,  9,  5, 10,  5,  2,  5,  6,  4,  1,  5],
#        device='cuda:0')
# tensor([11,  0,  8,  6,  2, 13, 13, 11,  3,  3,  5,  9, 11,  6,  9,  9],
#        device='cuda:0') tensor([11,  0,  3,  6,  2, 13, 13,  6,  3,  3,  5,  9,  1,  6, 10,  9],
#        device='cuda:0')
# tensor([12,  3, 10,  8,  0,  3,  0, 13,  0,  9, 10,  9,  3,  2,  6, 13],
#        device='cuda:0') tensor([12,  3, 10,  8,  0,  5,  6, 13,  0,  9,  6,  9,  5,  9, 10, 12],
#        device='cuda:0')
# tensor([ 3,  3, 13, 10, 11,  0,  2,  3,  6,  7,  7,  3,  2,  7,  3,  6],
#        device='cuda:0') tensor([ 3,  3, 13, 10,  7,  7, 11,  3,  1,  7,  7, 13,  2,  7,  3,  8],
#        device='cuda:0')
# tensor([ 1, 13, 12,  1,  7, 12,  6, 13, 13,  5,  9,  6,  6, 12,  2,  1],
#        device='cuda:0') tensor([ 1,  0, 11,  1,  7, 12,  9, 13, 13,  5,  0,  0,  1, 12,  2,  1],
#        device='cuda:0')
# tensor([13, 12,  9, 10,  2,  0,  1,  5,  6,  6, 10,  5,  3,  1,  6, 13],
#        device='cuda:0') tensor([13, 12,  1, 10,  2,  0,  1,  2,  6, 10,  0,  5,  8,  1, 11, 13],
#        device='cuda:0')
# tensor([ 2, 10, 12,  6,  6, 13, 13,  6, 13,  3,  5,  2,  5,  6,  1,  1],
#        device='cuda:0') tensor([ 2, 10, 12,  7,  6, 13,  7,  6, 10,  3,  3,  8,  3,  6,  2,  1],
#        device='cuda:0')
# tensor([10,  1, 10, 10,  9,  6,  8,  2, 12,  1, 11,  6,  6, 13,  2, 13],
#        device='cuda:0') tensor([ 0,  1, 10, 10,  9,  9,  2,  3, 12,  1, 11,  0,  6, 13,  2, 12],
#        device='cuda:0')
# tensor([ 5, 11,  9,  9,  1, 11, 13, 13,  2,  2, 12,  2,  1,  0,  7,  7],
#        device='cuda:0') tensor([ 5, 11,  9,  9,  8, 11, 13, 13,  8,  2, 11,  6,  1,  9,  7,  7],
#        device='cuda:0')
# tensor([13,  9,  9,  3, 11,  6, 12,  2,  2, 12, 12, 10,  3,  6, 10, 10],
#        device='cuda:0') tensor([13, 10,  9, 10, 11,  6, 12,  2,  2, 12, 12, 10,  3,  6, 10,  0],
#        device='cuda:0')
# tensor([ 3, 13, 11,  8, 13, 13,  6,  7,  6, 11,  7,  6,  1,  5,  1,  0],
#        device='cuda:0') tensor([ 5,  2, 11,  8, 13, 13,  6,  3,  0, 10,  7,  0,  1,  7,  1,  0],
#        device='cuda:0')
# tensor([ 5,  8,  9,  6,  3,  2,  6, 13,  9,  8, 10,  9,  3, 13,  9,  8],
#        device='cuda:0') tensor([ 5,  8,  7,  6,  3,  3,  6, 13,  7,  8,  0,  9,  3, 12,  9,  8],
#        device='cuda:0')
# tensor([ 8, 13,  9, 11,  2,  8,  7,  1,  5,  6,  5, 13,  5,  2,  7, 13],
#        device='cuda:0') tensor([ 8, 13,  9,  9,  2,  8,  7, 10,  5,  6,  7, 13,  5,  2,  5, 13],
#        device='cuda:0')
# tensor([12,  9,  0,  5,  8,  9,  9,  7, 11,  3,  8, 13,  6,  1, 10,  0],
#        device='cuda:0') tensor([10,  9,  2,  3,  8,  1,  9,  7, 11,  3,  8, 13,  6,  6,  6,  0],
#        device='cuda:0')
# tensor([ 1,  1, 10, 13,  3,  0,  3,  2,  1, 12,  8,  9,  3, 10, 13, 13],
#        device='cuda:0') tensor([ 1,  1, 10,  1,  5,  0,  5,  2,  1, 12,  2,  6,  3, 12, 13, 13],
#        device='cuda:0')
# tensor([12,  1,  2,  7,  6, 11,  9,  3,  2, 10,  0, 13, 12,  9,  0, 10],
#        device='cuda:0') tensor([12,  1, 13,  7, 10, 11, 10,  3, 13, 10,  0, 13, 11,  9,  0, 10],
#        device='cuda:0')
# tensor([13,  1,  0, 13,  5,  3,  7,  6,  7,  1,  0,  8, 10,  1, 10,  6],
#        device='cuda:0') tensor([ 2,  9,  0, 13,  5,  5,  7,  2,  7,  1, 11,  8,  0,  1, 10, 10],
#        device='cuda:0')
# tensor([12,  3, 12, 10,  0,  9,  1,  5, 11,  9, 13, 13,  2,  5,  1,  9],
#        device='cuda:0') tensor([12,  5, 12,  6,  0, 11,  1,  5, 11,  9,  2, 13, 13,  5,  1,  9],
#        device='cuda:0')
# tensor([ 6,  7,  3,  3,  9,  0, 11, 11, 12,  1,  3,  5,  5,  1,  3, 11],
#        device='cuda:0') tensor([ 6,  3,  3,  3,  0,  0, 11, 11, 12,  1,  0,  7,  5,  1,  3, 11],
#        device='cuda:0')
# tensor([12, 10,  5,  1,  0,  8, 10, 10, 10, 11,  9,  6,  7, 11,  5,  5],
#        device='cuda:0') tensor([11, 10,  5,  1,  9,  8, 10, 10,  6, 11,  2,  0,  7, 11,  5,  1],
#        device='cuda:0')
# tensor([ 0,  4, 10,  0, 11,  3,  6,  2, 10,  7,  0,  6,  3,  6,  6, 10],
#        device='cuda:0') tensor([ 0,  7, 10,  0,  1,  3,  6,  2, 10,  3,  0,  9,  4,  6,  6, 10],
#        device='cuda:0')
# tensor([12,  3, 13, 11,  2,  5,  8, 13, 10,  7, 10, 11,  3,  6,  5,  2],
#        device='cuda:0') tensor([12,  5, 13, 11,  2,  3,  5, 13, 10,  7, 10, 11,  3,  1,  3,  2],
#        device='cuda:0')
# tensor([12, 11, 11,  1,  7,  8,  9,  3, 10,  9,  2, 13,  3,  7, 12,  5],
#        device='cuda:0') tensor([12,  0, 11,  1,  4,  6,  9,  3, 10,  9, 12, 13,  3,  0, 12,  5],
#        device='cuda:0')
# tensor([ 6, 12,  2,  3, 13, 10,  5,  2,  9,  3, 10, 11,  3, 12,  5,  9],
#        device='cuda:0') tensor([ 6, 12,  2,  1, 13,  7,  5, 11,  9,  3,  8,  1,  2, 12,  5,  8],
#        device='cuda:0')
# tensor([ 9,  5, 10, 10, 13,  3, 13, 12, 11,  7, 12, 10, 11,  3, 13,  7],
#        device='cuda:0') tensor([ 9,  7,  0,  2, 13,  3,  4, 12,  6,  7, 12, 11, 11,  3, 13,  7],
#        device='cuda:0')
# tensor([ 9, 10,  1,  3,  6,  6,  0,  5,  2,  3,  8, 12,  3, 10, 10,  8],
#        device='cuda:0') tensor([ 9, 12,  1,  3,  6,  6,  9,  5,  2,  3,  8, 12,  0, 10,  9,  1],
#        device='cuda:0')
# tensor([ 3, 10,  1,  6, 12,  1,  7,  8,  1, 10,  1,  2, 10, 13,  5, 13],
#        device='cuda:0') tensor([ 3,  6,  1,  6, 12,  1,  3,  8,  9, 10,  1,  2, 10, 13,  5, 13],
#        device='cuda:0')
# tensor([ 7, 11, 10, 10,  2, 13,  9, 12, 11,  0, 12,  0, 13,  3,  2,  1],
#        device='cuda:0') tensor([ 5, 12, 10, 10,  2,  0,  0, 12, 11,  9,  1,  9,  9,  6,  2,  1],
#        device='cuda:0')
# tensor([ 7, 10,  9,  3, 13, 13,  2,  5, 12,  8, 10,  5, 11,  6,  1,  8],
#        device='cuda:0') tensor([ 0, 10,  9,  3, 13, 12,  2,  3, 12,  0, 10,  5, 11,  6,  1,  8],
#        device='cuda:0')
# tensor([ 8, 12,  2,  5,  3,  0, 10,  3,  5,  1, 12, 12, 11, 11, 13,  2],
#        device='cuda:0') tensor([ 8, 12,  2,  5,  9, 11,  3,  2,  5,  1, 12, 12,  9, 11, 13, 11],
#        device='cuda:0')
# tensor([ 7,  2,  3, 13, 10, 11,  7,  5,  1, 11,  0,  8,  0, 13, 13, 11],
#        device='cuda:0') tensor([ 7,  2,  8, 13, 10, 11,  0,  1,  1, 11, 12,  8,  6, 13, 13, 11],
#        device='cuda:0')
# tensor([12,  6,  8,  1,  3, 11, 10,  7,  9, 13,  5,  6, 13, 13, 11, 13],
#        device='cuda:0') tensor([12,  0,  8,  1,  3, 11,  8,  7,  0, 13,  5,  6,  1, 13, 11, 13],
#        device='cuda:0')
# tensor([ 0, 10, 12,  2,  0,  9, 13,  3,  3, 11,  6,  9,  1,  7,  8, 12],
#        device='cuda:0') tensor([ 0, 10, 12, 13,  0,  9, 13,  5,  5, 11,  0,  0,  8,  7,  8, 12],
#        device='cuda:0')
# tensor([11,  3, 13,  0,  6,  5, 13,  7,  0, 10,  7, 13,  5,  6, 13,  4],
#        device='cuda:0') tensor([ 1,  3, 13,  0,  9,  5, 13,  7,  9, 10,  7,  1,  5,  9, 13,  3],
#        device='cuda:0')
# tensor([ 3, 13, 13,  5,  5,  8, 13,  2,  9,  0,  7,  3,  0, 13, 11,  7],
#        device='cuda:0') tensor([ 3, 13, 13,  5,  5,  8, 13,  2,  9, 10,  7,  3,  0, 13,  9,  7],
#        device='cuda:0')
# tensor([ 3,  3,  6,  7,  2, 10,  8, 12, 12, 10, 10,  9,  1,  1,  3, 11],
#        device='cuda:0') tensor([ 1,  3,  6,  2,  5,  0,  8, 12, 12, 10, 10,  7,  1,  1,  9, 11],
#        device='cuda:0')
# tensor([ 3,  9,  0, 13,  3,  0, 11,  3, 10,  0,  5,  7,  6,  3,  1,  3],
#        device='cuda:0') tensor([ 3,  9,  0, 13, 12,  1,  6,  7, 10, 11,  1,  2, 10,  5, 10,  3],
#        device='cuda:0')
# tensor([ 0, 12, 10, 12,  1, 12,  8,  5,  1,  7, 13, 13,  2,  5,  7,  2],
#        device='cuda:0') tensor([ 0, 12, 10, 12,  1, 12,  1,  5,  1,  7, 13,  7,  2,  7,  7,  2],
#        device='cuda:0')
# tensor([10, 13,  6,  5,  3, 13, 12, 12,  2,  7, 10,  3, 12, 13,  8, 10],
#        device='cuda:0') tensor([10, 13,  0,  5,  3, 13, 12,  8,  2,  7, 10,  3, 12, 13,  8, 10],
#        device='cuda:0')
# tensor([ 8,  0,  3, 13,  1,  5,  3, 12,  8,  1,  3,  6, 13,  5,  9,  9],
#        device='cuda:0') tensor([ 6,  0,  3, 13,  1,  9,  0, 13,  8,  1,  3,  9, 12,  5,  3,  1],
#        device='cuda:0')
# tensor([10,  2,  7,  0,  0,  8, 10,  7,  2,  4, 12,  2, 11,  8,  5, 12],
#        device='cuda:0') tensor([ 0,  2,  7, 10,  9,  9, 10,  7,  2,  4,  2,  1, 12,  8, 10,  9],
#        device='cuda:0')
# tensor([ 1,  3, 10, 13,  3, 10,  0,  1,  3,  3,  5, 10, 13, 13,  5,  5],
#        device='cuda:0') tensor([ 1,  7, 10,  5,  3,  0,  9,  1,  8,  3,  3, 10,  9, 13,  5,  5],
#        device='cuda:0')
# tensor([ 2,  7,  3,  8,  3,  6,  9,  9,  7, 12,  3,  6, 13,  9,  3,  0],
#        device='cuda:0') tensor([12,  7,  3,  8,  3,  0,  9,  9, 11, 12,  5,  0,  1,  2,  7,  1],
#        device='cuda:0')
# tensor([ 7, 11,  3,  6,  8, 13,  8,  6,  7,  0,  5,  8,  2, 11, 12, 10],
#        device='cuda:0') tensor([ 7, 11,  3,  6,  8, 13,  0,  1,  4, 11,  7,  8,  2, 12, 11,  0],
#        device='cuda:0')
# tensor([10,  2, 10,  5,  6, 10,  1,  6,  7, 11,  2,  7,  5,  5, 13,  7],
#        device='cuda:0') tensor([10,  2,  8,  5,  6, 12,  1,  6,  7, 11,  2,  5,  3,  7,  3,  7],
#        device='cuda:0')
# tensor([13,  3,  9, 10, 10, 10, 13,  9, 12,  5, 12, 11,  4,  9, 11, 12],
#        device='cuda:0') tensor([13,  3,  1, 10,  6,  0, 13,  7, 13,  5, 12, 11,  4,  9, 11,  5],
#        device='cuda:0')
# tensor([ 7, 10,  6,  3,  7,  8,  5,  3,  5, 12,  3, 10,  0,  6,  9,  9],
#        device='cuda:0') tensor([ 7, 10,  6,  7,  3,  8,  5,  4,  5, 12,  3, 10, 10,  6,  9,  9],
#        device='cuda:0')
# tensor([ 5,  5,  8,  9, 11, 12,  5, 12, 10, 13,  7,  7, 13, 10,  8,  1],
#        device='cuda:0') tensor([ 5,  3,  2,  9,  7, 12,  4, 12, 10, 13,  7,  7, 13, 10,  8,  1],
#        device='cuda:0')
# tensor([ 0,  9, 13,  1,  9,  6,  6,  0,  2,  0,  3,  0,  8,  5, 10,  6],
#        device='cuda:0') tensor([ 0,  9, 13, 11,  0,  6,  6,  1,  8,  0,  0,  0,  8,  5,  9,  1],
#        device='cuda:0')
# tensor([ 2, 13,  8,  8,  9, 12,  6,  3, 13,  0, 10,  0,  0,  7,  2, 10],
#        device='cuda:0') tensor([ 2, 13,  0,  8,  9, 12,  8,  8, 13,  0, 10,  0,  0,  7,  2, 10],
#        device='cuda:0')
# tensor([ 0,  1,  0,  0, 13,  2,  8, 12, 11,  8,  3,  8, 13,  3, 12, 12],
#        device='cuda:0') tensor([ 0,  1,  0, 10, 13, 12,  8, 12, 11,  0,  3,  8, 13,  3,  7,  3],
#        device='cuda:0')
# tensor([ 7,  1,  3,  9, 11,  7, 10, 10, 11,  9,  7,  1,  3,  0,  9,  8],
#        device='cuda:0') tensor([ 7,  1,  3,  9, 11,  7,  0, 10, 11,  1,  7,  1,  3,  0,  9, 12],
#        device='cuda:0')
# tensor([ 0, 10,  0,  2,  3,  8,  0,  1, 13,  3,  8,  3,  9, 10, 11,  9],
#        device='cuda:0') tensor([ 9,  0,  0,  2,  9,  8,  9,  1, 12,  3,  2,  3,  9,  9, 11,  9],
#        device='cuda:0')
# tensor([ 5,  8, 12,  0,  3,  6,  3,  6,  7,  5,  6, 11,  9,  6,  7, 13],
#        device='cuda:0') tensor([ 5,  8, 12,  2,  3,  6,  3,  6,  8,  3,  6,  6,  2,  6,  7,  1],
#        device='cuda:0')
# tensor([13,  2,  7, 10,  9, 13, 13,  7,  8,  4,  6, 10, 12,  8, 10,  4],
#        device='cuda:0') tensor([13,  2,  7, 10,  9,  8, 13,  7,  8,  4,  6, 10, 12,  8, 10,  4],
#        device='cuda:0')
# tensor([13,  7, 11,  2,  1,  6, 13,  8,  6,  7, 12,  3,  0, 12,  0,  7],
#        device='cuda:0') tensor([13,  7, 11,  2,  2,  6, 11,  8,  3,  7, 12,  3,  0, 12,  0,  0],
#        device='cuda:0')
# tensor([10, 13,  0,  8, 13, 13, 13,  6,  7,  1, 13,  0, 12, 10,  6, 11],
#        device='cuda:0') tensor([ 6, 13,  6,  8, 13,  2, 13,  6,  7,  1, 13,  0, 12,  9, 10,  9],
#        device='cuda:0')
# tensor([10,  1, 10,  0,  0, 10, 11,  0, 10,  7,  0, 10,  8, 11, 10,  5],
#        device='cuda:0') tensor([11,  1, 10, 10,  0, 10,  7,  0, 10,  7, 10, 10,  8,  1,  8,  5],
#        device='cuda:0')
# tensor([ 4, 13,  3,  5, 10,  1, 13,  3,  1,  9,  9,  2,  7, 13,  7, 10],
#        device='cuda:0') tensor([ 8, 13,  6,  5, 10,  1, 12,  3, 10,  9,  7,  2,  7, 13,  7,  5],
#        device='cuda:0')
# tensor([12, 13,  2,  7, 11,  5,  2, 12,  7,  3,  9, 12, 10, 13, 10,  0],
#        device='cuda:0') tensor([12, 13, 10,  7,  9, 10,  2, 12,  7,  5,  9, 12,  0, 13,  0,  0],
#        device='cuda:0')
# tensor([ 8, 10,  0, 11, 11,  2,  3, 12,  2,  0,  0,  3,  3,  0,  6,  0],
#        device='cuda:0') tensor([ 1,  6,  2,  1, 11,  2,  3,  7,  2,  0,  0,  3,  8,  6,  9,  0],
#        device='cuda:0')
# tensor([ 7,  3,  7,  0, 13,  1,  2,  6, 13,  0,  0,  3,  0, 13,  9, 13],
#        device='cuda:0') tensor([ 7, 11,  7,  6,  7,  8,  2,  6, 13,  9,  8,  3, 11, 13,  9, 13],
#        device='cuda:0')
# tensor([ 9,  3,  2, 10,  0,  1,  2,  9,  7, 12,  5, 12,  9, 11,  2,  5],
#        device='cuda:0') tensor([ 9,  3,  2, 10,  0,  1,  2,  9,  7,  6,  5, 12,  9, 11,  2,  7],
#        device='cuda:0')
# tensor([ 7, 12,  8, 12,  8,  7, 10,  7,  9,  2,  9, 12, 10,  3,  9,  5],
#        device='cuda:0') tensor([ 7, 12,  8, 11,  8,  7, 10,  7,  9,  2,  0,  3, 10,  3,  0,  5],
#        device='cuda:0')
# tensor([13, 10, 10,  7,  2, 13,  5,  5,  5,  0,  0,  4, 10, 10,  7,  9],
#        device='cuda:0') tensor([13, 10, 10,  7,  2, 13,  3,  5,  3,  7,  1,  7,  0, 10,  7,  8],
#        device='cuda:0')
# tensor([10, 13, 13,  8,  2,  9,  8, 13,  0, 13,  7,  9, 10,  3, 11, 10],
#        device='cuda:0') tensor([ 6, 13, 13, 10,  7,  6,  8, 13,  0,  3,  7,  0, 10,  3, 12, 10],
#        device='cuda:0')
# tensor([ 1,  5,  9,  3,  1, 11,  7, 13,  2,  1,  0,  8,  7, 13,  7,  7],
# ...
#        device='cuda:0') tensor([ 9,  6,  7, 12,  0,  0,  1,  6, 11,  3,  0, 11,  8,  1,  3,  8],
#        device='cuda:0')
# tensor([10, 13,  5,  7,  3,  0,  3,  1,  7, 10, 13,  5,  5,  9,  9, 11],
#        device='cuda:0') tensor([ 8, 12,  5,  7,  8,  1,  3,  1,  7,  1, 13,  5,  5,  6,  7, 11],
#        device='cuda:0')
# tensor([ 5, 13,  2,  2, 10,  6,  5,  2,  3, 11, 10,  5,  3, 13,  3,  7],
#        device='cuda:0') tensor([ 5, 13,  2,  9,  8, 10,  2,  2,  3,  2, 10,  5,  3, 12,  3,  5],
#        device='cuda:0')
# tensor([ 2,  7,  0, 11,  0,  0,  3,  7,  0,  7,  3,  5, 12,  2, 13,  6],
#        device='cuda:0') tensor([ 0,  0,  0, 13,  1,  0,  3,  7,  9,  7,  3,  5, 12,  2,  8,  6],
#        device='cuda:0')
# tensor([ 4, 13,  8,  8,  8,  8, 13,  8,  0, 12, 10,  0,  8, 10, 10,  3],
#        device='cuda:0') tensor([ 5, 13,  8,  8, 11,  8, 13,  8,  0,  9, 10,  9,  9,  7, 10,  3],
#        device='cuda:0')
# tensor([ 1,  0,  2,  3, 10,  0, 13, 12,  0, 10, 10,  3, 13,  6,  9,  0],
#        device='cuda:0') tensor([ 1,  9,  2,  3, 10,  0, 12, 12,  6, 10, 10,  3, 13,  6,  9,  0],
#        device='cuda:0')
# tensor([ 9,  2,  1, 11,  2, 11,  7, 12, 12, 12,  0,  2,  8,  3, 11,  6],
#        device='cuda:0') tensor([ 9,  2,  1, 11,  2, 11,  7, 11,  8, 12, 11,  6,  8,  3, 11,  6],
#        device='cuda:0')
# tensor([11,  5,  8, 10,  9,  2,  0,  3, 11, 12,  9,  9,  0,  8, 11, 10],
#        device='cuda:0') tensor([11,  5,  8,  0,  9, 10,  0,  4, 11, 13,  6,  0,  7,  8, 11, 10],
#        device='cuda:0')
# tensor([ 5,  3,  6,  9,  5,  5, 12, 12,  5, 10,  3, 11, 13,  5,  3,  6],
#        device='cuda:0') tensor([ 5,  3, 12,  4,  5,  5, 12,  6,  7, 10,  3,  2,  1,  5,  3,  6],
#        device='cuda:0')
# tensor([13,  3, 12,  5,  6, 12,  2,  8,  0, 13,  5,  3,  1, 11,  9,  8],
#        device='cuda:0') tensor([ 1,  3, 12,  5,  7, 12,  2,  1, 11, 13,  5,  3,  1,  6,  9,  8],
#        device='cuda:0')
# tensor([12,  8, 12,  5,  8, 13, 12,  3,  6, 12,  7, 13, 11,  8, 13, 13],
#        device='cuda:0') tensor([12,  8, 11,  5,  8, 13, 12,  7,  0, 12,  7, 13,  1,  8, 13, 13],
#        device='cuda:0')
# tensor([12,  7,  2, 11, 12,  2, 12,  8, 13,  3,  7, 12,  8,  5,  7,  7],
#        device='cuda:0') tensor([12,  7,  2, 11, 12,  2, 12,  8, 13,  7,  2, 12,  8,  3,  7,  5],
#        device='cuda:0')
# tensor([ 0, 10,  6,  0,  5,  8, 13, 10, 11,  3,  8,  3,  8,  7,  5, 13],
#        device='cuda:0') tensor([ 0,  6,  1,  0,  5,  8, 12, 10,  2,  3,  8,  8,  1,  7,  5, 13],
#        device='cuda:0')
# tensor([10, 11,  0, 12, 10,  3,  6,  3,  4,  2, 12,  9, 11,  3,  9,  9],
#        device='cuda:0') tensor([10,  0, 12, 12, 10,  3,  6,  3,  4,  1, 12,  9, 11,  3,  9,  9],
#        device='cuda:0')
# tensor([ 3,  0,  3,  0,  0, 12,  8, 12,  9,  4, 13,  8,  6,  8,  6,  0],
#        device='cuda:0') tensor([ 3,  0,  3,  0,  1, 12,  8, 12,  9,  4, 13,  8,  6,  8,  6,  6],
#        device='cuda:0')
# tensor([ 5,  3,  1,  5, 12,  7,  3,  0,  0,  0,  6, 12,  1,  9,  2, 12],
#        device='cuda:0') tensor([ 5,  3,  1, 10,  0,  7,  3,  9,  0,  9,  6,  9,  0,  9,  2,  0],
#        device='cuda:0')
# tensor([ 1, 11,  4,  2,  0,  5,  5,  5,  2,  7, 10, 11,  6, 11,  3, 11],
#        device='cuda:0') tensor([ 1, 11,  4,  2,  0,  5,  2,  5,  2,  7, 10,  6,  1, 11,  7, 11],
#        device='cuda:0')
# tensor([ 1, 13,  1,  7,  5, 11,  9,  2,  7, 12,  8,  9,  3,  9,  8,  7],
#        device='cuda:0') tensor([ 1, 10, 13,  7,  5, 11, 11,  1,  3,  1,  3,  9, 10,  9,  1,  3],
#        device='cuda:0')
# tensor([ 0,  7, 10,  5, 13,  8,  7,  1,  2, 12,  2,  1, 13, 11, 13,  8],
#        device='cuda:0') tensor([11,  7, 10,  5,  7,  8,  7,  2,  8, 12,  2,  1, 13, 11, 13,  6],
#        device='cuda:0')
# tensor([ 2,  8,  3, 13,  6,  8, 10,  5,  0,  3,  3,  8,  2,  3,  7,  0],
#        device='cuda:0') tensor([ 2,  8,  5, 13, 10,  9,  8,  8,  0,  5,  5,  8,  2,  7,  7,  0],
#        device='cuda:0')
# tensor([ 3,  9,  8,  5,  0,  1,  8, 11,  3,  2,  3, 10,  5, 10,  2,  8],
#        device='cuda:0') tensor([ 3,  9,  8,  5, 11,  1,  8,  1,  3, 10,  3, 10,  5, 10,  2,  2],
#        device='cuda:0')
# tensor([ 8,  8,  3,  3,  3,  5,  3,  3,  8, 10,  0,  3,  9,  7, 12, 13],
#        device='cuda:0') tensor([ 8,  8,  5,  3,  7,  5,  7,  3,  8, 10,  0,  7,  9,  3, 12, 13],
#        device='cuda:0')
# tensor([ 5,  3, 13,  9,  8, 12,  9,  3, 12,  7,  7,  3, 12, 12, 13,  3],
#        device='cuda:0') tensor([ 5,  3, 13,  9,  8, 12,  9,  5, 12,  7,  9,  3, 12,  3, 13,  7],
#        device='cuda:0')
# tensor([10, 12,  5,  2,  0, 13, 10,  2, 10,  2,  9,  7,  8,  9,  3, 11],
#        device='cuda:0') tensor([10, 12,  5,  2,  6, 13,  0,  2, 10,  2,  0,  7,  3,  9,  3, 11],
#        device='cuda:0')
# tensor([ 4, 11,  7, 10,  6,  3,  1, 13, 12, 12,  3,  0,  3, 10, 13, 13],
#        device='cuda:0') tensor([ 4,  7,  7,  6,  6,  3,  1, 13, 12, 12,  3,  0,  9, 10, 10, 13],
#        device='cuda:0')
# tensor([12,  2,  9,  1,  2,  0,  8,  0,  0, 13,  3,  9,  6,  3, 10, 10],
#        device='cuda:0') tensor([12,  2,  9,  1,  2, 10,  8,  0,  0, 13,  3,  0,  6,  3, 10, 10],
#        device='cuda:0')
# tensor([ 1, 10,  2,  8, 12, 13, 13, 13,  3,  8,  3,  0,  9,  9,  6, 12],
#        device='cuda:0') tensor([ 1, 10,  2,  0, 12, 12, 13, 13,  3,  8,  3,  0,  0,  1,  6, 12],
#        device='cuda:0')
# tensor([ 9,  3, 10,  3,  1, 13,  2, 10, 13,  0,  5,  2,  7,  5,  1,  9],
#        device='cuda:0') tensor([ 2,  3,  8,  2,  1, 13,  2,  9, 13,  6,  7,  2,  7,  3, 12, 11],
#        device='cuda:0')
# tensor([ 3, 13,  9,  5, 13, 11, 12, 10, 13,  6, 12,  9,  9,  7, 13, 12],
#        device='cuda:0') tensor([12, 12,  1,  5, 13, 11, 12,  1,  9, 10, 12,  9,  9,  7, 13, 12],
#        device='cuda:0')
# tensor([10,  3, 10,  1,  7, 13,  2,  1,  2,  3, 13,  9,  3,  5,  1, 11],
#        device='cuda:0') tensor([10,  3, 10,  1,  7, 13,  2,  1,  1,  3, 13,  9,  3,  3,  1, 11],
#        device='cuda:0')
# tensor([10, 10, 13,  0, 12, 10,  8, 10,  5,  6, 12,  8, 13,  7,  1,  8],
#        device='cuda:0') tensor([10, 10,  2,  0, 13, 10,  8,  9,  5,  6, 12,  8, 13,  1,  9,  9],
#        device='cuda:0')
# tensor([ 3,  9,  5,  7,  8, 11, 12,  2,  7,  9,  0, 13,  9,  5, 13,  5],
#        device='cuda:0') tensor([ 9,  9,  3,  7,  8, 11, 12,  2,  7,  9,  6, 12,  9,  3, 13,  5],
#        device='cuda:0')
# tensor([11, 13, 11,  3, 12, 11,  9,  8, 13,  8,  5,  8, 10,  3,  6,  8],
#        device='cuda:0') tensor([ 2, 13, 11,  9, 12, 11,  9,  8, 13,  8,  5,  2,  6,  3,  6,  2],
#        device='cuda:0')
# tensor([ 8,  3, 13,  6, 12,  3,  2, 11, 12,  6,  7,  0,  7,  7,  9,  1],
#        device='cuda:0') tensor([ 0, 10, 13,  6, 12,  7,  2, 11, 12,  4,  7,  0,  7,  7,  9,  2],
#        device='cuda:0')
# tensor([ 1,  4,  1,  6, 11,  2,  8,  8, 12, 10,  3,  2,  8,  1, 10,  0],
#        device='cuda:0') tensor([ 1,  4,  3,  6, 10,  2,  8,  6, 12, 10,  3,  2,  8,  1,  0,  8],
#        device='cuda:0')
# tensor([ 9,  2, 13,  7,  5,  7,  1,  0,  7, 10,  1,  3, 12,  8,  7,  3],
#        device='cuda:0') tensor([ 9,  2,  3,  7,  5,  7,  1,  1,  7, 10, 10,  1, 12,  8,  7,  3],
#        device='cuda:0')
# tensor([12,  7,  7, 13,  0,  3, 11, 11, 10, 13,  3, 13, 10,  0,  3,  8],
#        device='cuda:0') tensor([ 0,  7,  7, 13,  3,  3,  2, 11, 10, 13,  3, 13, 10,  0,  7,  0],
#        device='cuda:0')
# tensor([ 7,  1, 12, 13,  9, 11,  5, 10,  7, 11, 12,  2, 12, 10, 11,  3],
#        device='cuda:0') tensor([ 7,  1, 13, 13,  3, 11,  5, 10,  7, 11, 12,  2, 11, 10, 11,  5],
#        device='cuda:0')
# tensor([10,  0,  0,  5,  0,  1, 13,  3, 12, 10,  1,  3, 12, 10,  2,  1],
#        device='cuda:0') tensor([10,  0, 12,  5,  6,  1, 13,  3, 12, 10,  1, 11, 12, 10,  2, 12],
#        device='cuda:0')
# tensor([ 7,  3,  7, 10, 13,  5,  9, 13,  3,  9,  0,  5,  0,  2,  5,  6],
#        device='cuda:0') tensor([ 7,  5,  7, 10, 10,  7,  6, 13,  3,  7,  8,  5,  0,  0,  3,  6],
#        device='cuda:0')
# tensor([ 7,  0,  5,  6, 10, 10,  2, 11, 13,  1,  5,  9, 13, 10,  1,  0],
#        device='cuda:0') tensor([ 7,  1,  4,  6, 10, 10,  2,  0,  2,  2,  5,  9, 13, 10,  1,  0],
#        device='cuda:0')
# tensor([10, 13, 12, 10,  3, 13,  7,  0,  0,  6,  8, 11,  7,  8, 10,  5],
#        device='cuda:0') tensor([10,  1, 12, 10,  3, 13,  7,  0,  4,  0,  8,  0,  3,  8, 10,  3],
#        device='cuda:0')
# tensor([ 8, 12,  8,  3,  6,  9,  7,  0,  4,  8,  5,  6, 13,  2,  5,  9],
#        device='cuda:0') tensor([ 6, 12,  8,  3,  1,  1,  5,  9,  4,  8,  5,  0,  9,  2,  5,  9],
#        device='cuda:0')
# tensor([12, 11,  3,  2,  3,  7,  3,  0,  5,  7, 13,  5,  7,  2, 10,  6],
#        device='cuda:0') tensor([ 9, 11,  3,  1,  3,  7,  7,  0,  5,  7, 13,  7,  5,  1, 10, 11],
#        device='cuda:0')
# tensor([ 0,  8,  2,  9,  6,  2, 11,  7,  3, 13,  5,  3, 13,  2,  9, 11],
#        device='cuda:0') tensor([ 9,  1,  2,  1,  6,  2, 13,  7,  5, 13,  5,  3, 13,  2, 12, 11],
#        device='cuda:0')
# tensor([12,  8, 10,  2, 11, 12, 10,  7,  2, 13,  3,  0, 13,  0, 13,  6],
#        device='cuda:0') tensor([12,  6,  0,  2, 11, 12, 10,  7,  2, 13,  3,  0, 11,  1, 13,  6],
#        device='cuda:0')
# tensor([ 3,  7,  3, 12, 12,  0,  2, 12,  4, 10, 13, 13,  0,  0,  7,  9],
#        device='cuda:0') tensor([ 3,  7,  3,  2, 12,  0, 11, 12,  4, 10,  8, 13,  0,  0,  7,  9],
#        device='cuda:0')
# tensor([ 3, 13,  9,  8, 12, 10,  6,  9,  2,  1, 10,  3,  9, 13,  7,  0],
#        device='cuda:0') tensor([ 3, 12,  9,  8, 12,  0,  6,  3,  2,  1,  0,  9,  4, 13,  7,  6],
#        device='cuda:0')
# tensor([ 0, 10,  8, 10, 10, 12, 13, 13,  8,  9,  7, 13, 13,  6,  9, 12],
#        device='cuda:0') tensor([ 0, 10,  9, 10,  2, 12, 13, 13,  8, 10,  1, 13, 13,  6,  5, 12],
#        device='cuda:0')
# tensor([ 3, 10, 10,  3,  0, 12,  1, 11, 13, 11, 10,  8,  2,  9,  9,  3],
#        device='cuda:0') tensor([ 3, 10, 10,  3,  6, 12,  1, 11,  1,  3,  7,  6,  2,  1,  4,  4],
#        device='cuda:0')
# tensor([ 7, 10,  0,  6, 10, 12, 10,  7, 12,  2,  1, 11,  0,  7,  3,  9],
#        device='cuda:0') tensor([ 7, 10,  9,  6,  9, 12, 10,  7, 12,  2, 12, 11,  6,  7,  2,  1],
#        device='cuda:0')
# tensor([12,  6, 11,  9,  8,  3,  8,  9,  6,  6,  2, 11, 13,  2, 11, 10],
#        device='cuda:0') tensor([12,  6, 11,  9,  8,  3,  8,  9,  6,  0,  2,  1, 13,  2, 11, 10],
#        device='cuda:0')
# tensor([ 8, 11, 12,  6, 13,  0, 10,  2, 10,  0,  7,  8, 11, 10, 11, 11],
#        device='cuda:0') tensor([ 2, 11, 12,  6, 13,  0, 10,  2, 10,  0,  7,  8, 11, 10, 11, 11],
#        device='cuda:0')
# tensor([ 5,  6,  5,  5,  1, 10,  6,  6, 13, 13, 12,  7, 11, 13, 10,  3],
#        device='cuda:0') tensor([ 5,  6,  5,  5,  1,  0, 10, 11, 13, 10, 12,  7, 12, 13, 10,  9],
#        device='cuda:0')
# tensor([ 9,  3, 13,  2, 10,  2, 12,  8,  0,  6,  3,  3, 12,  1,  0,  3],
#        device='cuda:0') tensor([ 3,  3, 10,  2,  0,  2, 12, 10,  6,  6,  7,  3, 12,  1,  9,  7],
#        device='cuda:0')
# tensor([11,  7,  0,  6,  4, 10,  3, 13,  3, 13,  6,  7, 11, 13, 13,  8],
#        device='cuda:0') tensor([11,  7, 10,  6,  4, 10,  3, 13,  3, 12,  6,  7, 12,  5, 13,  1],
#        device='cuda:0')
# tensor([ 0,  6,  0,  1, 10,  2,  2,  2,  9,  6,  7,  7,  9, 11,  5,  5],
#        device='cuda:0') tensor([ 6,  0,  1,  1, 10,  7,  2,  2,  1,  6,  7,  7,  9, 11,  3,  5],
#        device='cuda:0')
# tensor([10,  7,  0, 12,  6,  7,  0, 13,  1,  2,  5, 13, 13, 13, 13,  2],
#        device='cuda:0') tensor([10,  7, 10, 11,  6,  7,  0, 13,  0, 12,  5, 13, 13, 13, 13,  2],
#        device='cuda:0')
# tensor([11, 12, 12,  5, 11,  0, 13,  5,  2,  8, 10, 13,  8, 10, 10,  3],
#        device='cuda:0') tensor([11, 12, 12,  5, 11,  1, 13,  5,  2,  8, 10, 13,  2, 10, 10,  7],
#        device='cuda:0')
# tensor([13, 12, 11,  1, 12,  9,  2, 12,  3, 13,  3, 13,  2, 11,  3,  2],
#        device='cuda:0') tensor([13, 12,  6,  5, 12,  9,  2, 12,  1, 13,  3, 13,  2, 11,  5, 10],
#        device='cuda:0')
# tensor([ 4,  0, 13,  3,  7,  5, 10,  2,  6, 11,  8,  1,  8, 10,  9,  5],
#        device='cuda:0') tensor([ 8,  4, 13,  3,  7,  5, 10,  2,  1, 11,  8,  1,  8,  6,  9,  5],
#        device='cuda:0')
# tensor([ 6,  6,  9,  1, 10, 13,  7, 10, 13, 11,  7,  1, 13, 11, 13,  8],
#        device='cuda:0') tensor([ 8,  6,  9,  1,  0, 13,  7,  1, 13, 11,  7,  1, 13,  9,  2,  9],
#        device='cuda:0')
# tensor([ 5,  5,  3, 12,  3,  1, 13, 12, 13, 11,  1,  7, 10,  7,  3,  2],
#        device='cuda:0') tensor([ 5,  5,  5, 11,  3,  1, 13, 12,  2, 11,  1,  7,  8,  7, 11,  2],
#        device='cuda:0')
# tensor([13,  8,  9,  1, 10,  6,  3,  6,  7, 12, 13,  0,  3, 12, 11, 13],
#        device='cuda:0') tensor([ 2,  1,  0,  1, 10,  6,  3, 13,  7, 12, 11,  6,  3,  0, 11, 13],
#        device='cuda:0')
# tensor([10, 12, 11, 11,  7,  7,  3,  4,  2, 13,  0, 13, 13,  8,  3,  7],
#        device='cuda:0') tensor([10, 12, 11, 11,  7,  7,  3,  4, 12, 13,  0, 13,  6,  8,  5,  4],
#        device='cuda:0')
# tensor([ 7,  1,  1, 10, 13,  6,  2, 10, 10, 12, 10,  3,  1,  0, 13, 11],
#        device='cuda:0') tensor([12,  1,  1,  6, 13,  6,  2, 13, 10, 10, 10,  2,  1,  6, 13, 11],
#        device='cuda:0')
# tensor([13,  3,  3,  9, 13,  1,  7,  2,  5, 12,  6,  2,  5,  1,  0, 12],
#        device='cuda:0') tensor([13,  5,  3,  0, 13,  1,  3,  2,  5,  3,  9,  2,  5,  1,  6, 11],
#        device='cuda:0')
# tensor([ 2,  2, 11, 13,  2,  6,  5, 11,  6,  8, 10, 13, 10, 10,  7, 13],
#        device='cuda:0') tensor([ 1, 13,  2, 13,  1,  6,  5, 11,  6, 11, 10,  2,  0, 11,  7, 13],
#        device='cuda:0')
# tensor([ 5, 11, 13,  6,  0, 13,  8, 13,  5,  2, 13, 10,  8, 12,  5,  7],
#        device='cuda:0') tensor([ 5,  1, 13,  6,  6, 13,  8, 13,  5,  2, 13, 10,  8,  0,  3,  7],
#        device='cuda:0')
# tensor([11,  0,  2, 13,  3, 10,  0,  0,  8, 11,  2,  6,  0, 10,  6,  3],
#        device='cuda:0') tensor([11, 10,  2, 13,  3, 10,  4,  0,  4, 11,  2,  6,  0, 10,  6,  3],
#        device='cuda:0')
# tensor([13,  0, 12,  5,  9,  6, 13,  8,  0, 12,  6,  8, 10,  7,  0, 10],
#        device='cuda:0') tensor([13,  0, 12,  5,  9,  6, 13,  9,  6,  0,  6,  6, 10,  7,  6,  1],
#        device='cuda:0')
# tensor([ 0, 11,  2,  3,  3, 13,  6,  0,  5,  6,  8, 13,  6,  5,  3,  1],
#        device='cuda:0') tensor([ 7, 10,  2,  3,  3, 13,  0, 12,  5,  6,  8, 13,  6,  5,  3,  1],
#        device='cuda:0')
# tensor([10,  5,  3,  6,  8,  6,  7,  3,  2,  3,  0, 11,  7,  8, 10,  3],
#        device='cuda:0') tensor([10,  5,  5,  9,  8,  6,  5,  3,  2,  3,  0, 11,  7,  8, 10,  3],
#        device='cuda:0')
# tensor([13,  0,  9,  0,  9,  9,  7,  1,  6,  2,  1, 13,  5,  8,  4,  0],
#        device='cuda:0') tensor([13, 11,  0,  9,  9,  9,  7, 12,  6,  2,  1, 13,  3,  8,  4,  1],
#        device='cuda:0')
# tensor([ 9,  9,  7, 11,  1,  5,  2,  3,  1, 13,  6, 10,  8,  3,  8,  3],
#        device='cuda:0') tensor([ 1,  0,  7, 11,  2,  7,  2,  5,  2, 10,  6, 10,  8,  5,  2,  3],
#        device='cuda:0')
# tensor([ 3, 12,  6, 11,  7, 13,  5, 10,  3,  0, 10,  0, 10,  0, 12,  2],
#        device='cuda:0') tensor([ 3, 12,  6, 11,  7, 13,  5, 10,  3,  9,  6,  6,  2,  0, 12,  2],
#        device='cuda:0')
# tensor([ 5, 13,  3,  0,  6, 10, 11, 10, 13,  0, 13, 11, 10,  3,  8, 10],
#        device='cuda:0') tensor([ 5, 13,  3,  6,  6, 10, 11, 10,  2,  0, 13, 13,  6, 11,  8, 10],
#        device='cuda:0')
# tensor([ 0,  3,  6,  1,  8, 10,  1, 10,  7,  3,  9,  1, 10, 10,  0,  8],
#        device='cuda:0') tensor([ 0,  5,  6,  9,  8,  6,  9,  0,  7,  3, 11,  9, 10, 10, 11,  8],
#        device='cuda:0')
# tensor([ 0, 10,  1,  9,  6,  2,  1,  0,  3, 10, 13, 13, 10,  0,  7,  8],
#        device='cuda:0') tensor([ 0,  6,  1,  9,  6,  2,  1,  9,  3, 10,  2,  9,  8,  0,  9,  9],
#        device='cuda:0')
# tensor([ 7,  3, 11,  1,  3, 13, 11,  2, 13, 10, 10, 11, 12,  5,  8,  0],
#        device='cuda:0') tensor([ 7,  5, 11,  1,  5,  2, 12,  2, 13, 10, 10, 11, 12,  5,  8,  0],
#        device='cuda:0')
# tensor([ 3, 12,  3,  8,  3,  5,  0, 12,  0,  6, 10,  1,  2,  3,  6, 11],
#        device='cuda:0') tensor([ 3, 12,  3,  9,  5,  5,  0, 12,  0, 11, 10,  1,  2,  3,  6,  7],
#        device='cuda:0')
# tensor([ 8,  0, 13,  5, 12, 12,  3, 11,  0,  5,  1,  0,  9,  6,  8,  7],
#        device='cuda:0') tensor([ 2,  1,  5,  5,  0, 12, 11,  1, 11,  5,  1, 11,  9,  6,  8,  7],
#        device='cuda:0')
# tensor([ 1,  9, 13,  0, 10,  3,  3,  8], device='cuda:0') tensor([ 1,  9, 13,  8, 10,  3,  3,  0], device='cuda:0')
# 0.0
